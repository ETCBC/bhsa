# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use(
    # 'bhsa',
    "bhsa:clone",
    version="2017",
    mod=("etcbc/lingo/heads/tf," "cmerwich/bh-reference-system/tf"),
    hoist=globals(),
)
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/2017</span>
# <b title="local release">data:</b> <span title="r0.1=#6e632909160ab8f4486d6c6e88dfc522ea2b4de3 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/lingo/heads/tf/2017</span>
# <b title="local release">data:</b> <span title="rv1.0=#b9852739f705ab1e1bf53a60bbd68f16b4e20d90 offline under ~/text-fabric-data">~/text-fabric-data/cmerwich/bh-reference-system/tf/2017</span>
# ...

# %%
v = F.otype.s("verse")[0]
results = ((v,),)
highlights = {1, 3, 7}

# %% [markdown]
# # Vanilla

# %%
A.show(results, highlights=highlights)
# Out:
# <p><b>result</b> <i>1</i></p>
# ...

# %% [markdown]
# # Cream

# %%
A.show(results, highlights=highlights, standardFeatures=True)
# Out:
# <p><b>result</b> <i>1</i></p>
# ...

# %% [markdown]
# # Chocolate

# %%
A.displaySetup(
    withNodes=True,
    standardFeatures=False,
    extraFeatures=[
        "pgn_prps",
        "pgn_prde",
        "pgn_verb",
        "pgn_prs",
        "pdp",
        "typ",
        "rela",
        "ls",
        "function",
        "det",
        "st",
        "lex",
        "nametype",
        "gn",
        "nu",
        "nme",
        "lex:gloss",
    ],
)

# %%
A.show(results, highlights=highlights)
# Out:
# <p><b>result</b> <i>1</i></p>
# ...

# %%
A.displayReset()

# %%
A.showContext()
# Out:
# <details ><summary><b>bhsa</b> <i>app context</i></summary>
#
# <details ><summary>1. afterChild</summary>
#
# {}
#
# </details>
# <details ><summary>2. allowedValues</summary>
#
#
# *   **`baseTypes`**:
#     *   `half_verse`
#     *   `sentence`
#     *   `sentence_atom`
#     *   `clause`
#     *   `clause_atom`
#     *   `phrase`
#     *   `phrase_atom`
#     *   `subphrase`
#     *   `word`
# *   **`condenseType`**:
#     *   `book`
#     *   `chapter`
#     *   `verse`
#     *   `half_verse`
#     *   `sentence`
#     *   `sentence_atom`
#     *   `clause`
#     *   `clause_atom`
#     *   `phrase`
#     *   `phrase_atom`
#     *   `subphrase`
# *   **`hiddenTypes`**:
#     *   `half_verse`
#     *   `sentence`
#     *   `sentence_atom`
#     *   `clause`
#     *   `clause_atom`
#     *   `phrase`
#     *   `phrase_atom`
#     *   `subphrase`
# *   **`textFormat`**:
#     *   **`lex-default`**: `word`
#     *   **`lex-orig-full`**: `word`
#     *   **`lex-orig-plain`**: `word`
# ...
