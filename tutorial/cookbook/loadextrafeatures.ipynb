# %% [markdown]
# # Loading features that are present but not loaded.
#
# There are quite a few features in the BHSA that are not loaded by default.
# If you need them, you can load them easily.

# %%
from tf.app import use

# %%
A = use("ETCBC/bhsa", hoist=globals())
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.4.0=#571428c995d309c43ff592f885a5ebb42a87be6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.7.1=#f9f50075d169820af90524e89f573b54e0b1adb4 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.0=#d74f7b52866927c316dfcaa2ac89eb51ea59c5dc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.0=#2fb9e94de8ffc07e9e515e3efa36e502f95bdcea offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/2021</span>
# This is Text-Fabric 9.1.4
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 122 features found and 0 ignored
# ...

# %% [markdown]
# Let's ask for the list of all features.

# %%
A.isLoaded()
# Out:
# __boundary__         computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __levDown__          computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __levUp__            computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __levels__           computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __order__            computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __rank__             computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __sections__         computed   ~/text-fabric-data/etcbc/bhsa/tf/2021
# __structure__        NOT LOADED
# book                 node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# book@am              node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# book@ar              node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# book@bn              node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# book@da              node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# book@de              node (str) ~/text-fabric-data/etcbc/bhsa/tf/2021
# ...

# %% [markdown]
# You can load extra features in the following way.
# See the [cheat sheet under `TF.load()`](https://annotation.github.io/text-fabric/tf/cheatsheet.html#loading).

# %%
TF.load("lex0", add=True)
# Out:
#   0.00s loading features ...
#    |     0.84s T lex0                 from ~/text-fabric-data/etcbc/bhsa/tf/2021
#   2.61s All additional features loaded - for details use TF.isLoaded()
# True

# %% [markdown]
# From Text-Fabric 9.1.5 onward, you can also use a simpler call.
# See the [cheat sheet under `A.load()`](http://localhost:8080/tf/cheatsheet.html#initialisation-configuration-meta-data-and-linking).
#
# Let's also load `rank_occ` and `root`:

# %%
A.load("rank_occ root")
# Out:
#   0.00s loading features ...
#    |     0.58s T rank_occ             from ~/text-fabric-data/etcbc/bhsa/tf/2021
#   2.26s All additional features loaded - for details use TF.isLoaded()
# True

# %% [markdown]
# We can now make use of the feature `root`:

# %%
F.root.freqList()[0:10]
# Out:
# (('HWH', 6905),
#  ('BN', 5694),
#  ('KLL', 5434),
#  ('<unknown>', 3493),
#  ('PNH', 2128),
#  ('BJT', 2064),
#  ('<MM', 1900),
#  ('JD', 1619),
#  ('>BH', 1220),
#  ('>NT', 1034))
