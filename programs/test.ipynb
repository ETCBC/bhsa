# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("ETCBC/bhsa", hoist=globals(), lgc=True)
# Out:
# Using TF app bhsa in /Users/dirk/github/annotation/app-bhsa/code
# Using etcbc/bhsa/tf - c in /Users/dirk/github
# Using etcbc/phono/tf - c in /Users/dirk/github
# Using etcbc/parallels/tf - c in /Users/dirk/github
# ...

# %%
v1 = T.nodeFromSection(("Genesis", 1, 1))
A.pretty(v1, fmt="text-phono-full")
# Out:
# <div class="verse   ltr " >
#
#     <div class="vl">
#         <div class="vrs ltr "><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></div>
#
#     </div>
#
# <div class="satom   ltr " >
#
#     <div class="sentence  ltr " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:1" sec="Genesis 1:1">sentence</a>   <span class="number">1</span>
#     </div>
#     <div class="atoms ltr ">
#
# <div class="catom   ltr " >
#
#     <div class="clause  ltr " >
# ...
