# %% [markdown]
# <img align="right" src="images/dans-small.png"/>
# <img align="right" src="images/tf-small.png"/>
# <img align="right" src="images/etcbc.png"/>
#
#
# ![mql](images/emdros.png)
#
# # TF from MQL
#
# This notebook can read an
# [MQL](https://emdros.org/mql.html)
# dump of a version of the [BHSA](https://github.com/ETCBC/bhsa) Hebrew Text Database
# and transform it in a Text-Fabric
# [Text-Fabric](https://github.com/Dans-labs/text-fabric)
# resource.
#
# ## Discussion
#
# The principled way of going about such a conversion is to import the MQL source into
# an [Emdros](https://emdros.org) database, and use it to retrieve objects and features from there.
#
# Because the syntax of an MQL file leaves some freedom, it is error prone to do a text-to-text conversion from
# MQL to something else.
#
# Yet this is what we do, the error-prone thing. We then avoid installing and configuring and managing Emdros, MYSQL/SQLite3.
# Aside the upfront work to get this going, the going after that would also be much slower.
#
# So here you are, a smallish script to do an awful lot of work, mostly correct, if careful used.
#
# # Caveat
#
# This notebook makes use of a new feature of text-fabric, first present in 2.3.12.
# Make sure to upgrade first.
#
# ```sudo -H pip3 install --upgrade text-fabric
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import yaml
from shutil import rmtree
from tf.fabric import Fabric
from tf.core.helpers import formatMeta
import utils

# %% [markdown]
# # Pipeline
# See [operation](https://github.com/ETCBC/pipeline/blob/master/README.md#operation)
# for how to run this script in the pipeline.

# %%
if "SCRIPT" not in locals():
    SCRIPT = False
    FORCE = True
    CORE_NAME = "bhsa"
    VERSION = "2021"
    RENAME = (
        ("g_suffix", "trailer"),
        ("g_suffix_utf8", "trailer_utf8"),
    )

# %%
def stop(good=False):
    if SCRIPT:
        sys.exit(0 if good else 1)

# %% [markdown]
# # Setting up the context: source file and target directories
#
# The conversion is executed in an environment of directories, so that sources, temp files and
# results are in convenient places and do not have to be shifted around.

# %%
repoBase = os.path.expanduser("~/github/etcbc")
thisRepo = "{}/{}".format(repoBase, CORE_NAME)

# %%
thisSource = "{}/source/{}".format(thisRepo, VERSION)
mqlzFile = "{}/{}.mql.bz2".format(thisSource, CORE_NAME)

# %%
thisTemp = "{}/_temp/{}".format(thisRepo, VERSION)
thisTempSource = "{}/source".format(thisTemp)
mqlFile = "{}/{}.mql".format(thisTempSource, CORE_NAME)
thisTempTf = "{}/tf".format(thisTemp)

# %%
thisTf = "{}/tf/{}".format(thisRepo, VERSION)

# %% [markdown]
# # Test
#
# Check whether this conversion is needed in the first place.
# Only when run as a script.

# %%
if SCRIPT:
    testFile = "{}/.tf/otype.tfx".format(thisTf)
    (good, work) = utils.mustRun(
        mqlzFile, "{}/.tf/otype.tfx".format(thisTf), force=FORCE
    )
    if not good:
        stop(good=False)
    if not work:
        stop(good=True)

# %% [markdown]
# # TF Settings
#
# We add some custom information here.
#
# * the MQL object type that corresponds to the Text-Fabric slot type, typically `word`;
# * a piece of metadata that will go into every feature; the time will be added automatically
# * suitable text formats for the `otext` feature of TF.
#
# The oText feature is very sensitive to what is available in the source MQL.
# It needs to be configured here.
# We save the configs we need per source and version.
# And we define a stripped down default version to start with.

# %%
slotType = "word"

# %%
genericMetaPath = f"{thisRepo}/yaml/generic.yaml"
coreMetaPath = f"{thisRepo}/yaml/core.yaml"

with open(genericMetaPath) as fh:
    genericMeta = yaml.load(fh, Loader=yaml.FullLoader)
    genericMeta["version"] = VERSION
with open(coreMetaPath) as fh:
    coreMeta = formatMeta(yaml.load(fh, Loader=yaml.FullLoader))
    
featureMetaData = {"": genericMeta, **coreMeta}
# Out:
# {'': {'dataset': 'BHSA',
#   'datasetName': 'Biblia Hebraica Stuttgartensia Amstelodamensis',
#   'author': 'Eep Talstra Centre for Bible and Computer',
#   'encoders': 'Constantijn Sikkel (QDF), Ulrik Petersen (MQL) and Dirk Roorda (TF)',
#   'website': 'https://shebanq.ancient-data.org',
#   'email': 'shebanq@ancient-data.org',
#   'version': '2021'},
#  'book': {'description': '✅ book name in Latin (Genesis; Numeri; Reges1; ...'},
#  'chapter': {'description': '✅ chapter number (1; 2; 3; ...'},
#  'code': {'description': '✅ identifier of a clause atom relationship (0; 74; 367; ...'},
#  'det': {'description': '✅ determinedness of phrase(atom) (det; und; NA.'},
#  'dist': {'description': '✅ distance to mother of the object (0; 1; 2; -6; -6; ...'},
#  'dist_unit': {'description': '✅ unit of measure for the dist feature (words; phrase_atoms; clause_atoms.'},
#  'distributional_parent': {'description': '✅ parent releationship between phrase/clause/sentence atoms ('},
#  'domain': {'description': '✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).'},
#  'function': {'description': '✅ syntactic function of phrase (Cmpl; Objc; Pred; ...'},
#  'functional_parent': {'description': '✅ parent releationship between phrases/clauses/sentences ('},
#  'g_cons': {'description': '✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...'},
#  'g_cons_utf8': {'description': '✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים'},
#  'g_lex': {'description': '✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...'},
#  'g_lex_utf8': {'description': '✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה'},
#  'g_nme': {'description': '✅ nominal ending pointed-transliterated (/IJM /ET /;J ...'},
#  'g_nme_utf8': {'description': '✅ nominal ending pointed-Hebrew (ים ֶ֜ת  ֵ֜י'},
#  'g_pfm': {'description': '✅ preformative pointed-transliterated (!J.O! !J:! !J:! !J.A! ...'},
#  'g_pfm_utf8': {'description': '✅ preformative pointed-Hebrew (יְ יְ יַּ'},
#  'g_prs': {'description': '✅ pronominal suffix pointed-transliterated (+OW +;HW ...'},
#  'g_prs_utf8': {'description': '✅ pronominal suffix pointed-Hebrew (ו ֵהוּ'},
#  'g_suffix': {'description': '✅ interword material pointed-transliterated (& 00 05 00_P ...'},
#  'g_suffix_utf8': {'description': '✅ interword material pointed-Hebrew (־ ׃'},
#  'g_uvf': {'description': '✅ univalent final consonant pointed-transliterated (~OW ~E ~@H ...'},
#  'g_uvf_utf8': {'description': '✅ univalent final consonant pointed-Hebrew (ֶ ָה'},
#  'g_vbe': {'description': '✅ verbal ending pointed-transliterated ([W. ...'},
#  'g_vbe_utf8': {'description': '✅ verbal ending pointed-Hebrew (וּ'},
#  'g_vbs': {'description': '✅ root formation pointed-transliteratedeg (]] ]HA] ...'},
#  'g_vbs_utf8': {'description': '✅ root formation pointed-Hebrew (הַ'},
#  'g_voc_lex': {'description': '✅ vocalized lexeme pointed-transliterated (B.: R;>CIJT BR> >:ELOHIJM'},
#  'g_voc_lex_utf8': {'description': '✅ vocalized lexeme pointed-Hebrew (בְּ רֵאשִׁית ברא אֱלֹהִים'},
#  'g_word': {'description': '✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM'},
#  'g_word_utf8': {'description': '✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים'},
#  'gn': {'description': '✅ grammatical gender (m; f; NA; unknown.'},
#  'isroot': {'description': 'unclear feature of clause atoms (false; true.'},
#  'kind': {'description': '✅ clause kind (VC (verbal); NC (nominal); WP (without predication)'},
#  'kq_hybrid': {'description': '❓ unclear, ketiv/qere related ('},
#  'kq_hybrid_utf8': {'description': '❓ unclear, ketiv/qere related ('},
#  'label': {'description': '✅ (half-)verse label (half verses: A; B; C; verses:  GEN 01,02'},
#  'language': {'description': '✅ of word or lexeme (Hebrew; Aramaic.'},
#  'lex': {'description': '✅ lexeme consonantal-transliterated (B R>CJT/ BR>[ >LHJM/'},
#  'lex_utf8': {'description': '✅ lexeme consonantal-Hebrew (ב ראשׁית֜ ברא אלהים֜'},
#  'lexeme_count': {'description': '✅ on words: the number of occurrences of its lexeme ('},
#  'ls': {'description': '✅ lexical set, subclassification of part-of-speech (card; ques; mult'},
#  'mother_object_type': {'description': '✅ phrase(atom): type its linguistic mother (clause; phrase; subphrase; word; NA.'},
#  'mother': {'description': '✅ linguistic dependency between textual objects ('},
#  'nme': {'description': '✅ nominal ending consonantal-transliterated (absent; n/a; JM, ...'},
#  'nu': {'description': '✅ grammatical number (sg; du; pl; NA; unknown.'},
#  'number': {'description': '✅ sequence number of an object within its context ('},
#  'pdp': {'description': '✅ phrase dependent part-of-speech (art; verb; subs; nmpr, ...'},
#  'pfm': {'description': '✅ preformative consonantal-transliterated (absent; n/a; J, ...'},
#  'prs': {'description': '✅ pronominal suffix consonantal-transliterated (absent; n/a; W; ...'},
#  'prs_gn': {'description': '✅ pronominal suffix gender (m; f; NA; unknown.'},
#  'prs_nu': {'description': '✅ pronominal suffix number (sg; du; pl; NA; unknown.'},
#  'prs_ps': {'description': '✅ pronominal suffix person (p1; p2; p3; NA; unknown.'},
#  'ps': {'description': '✅ grammatical person (p1; p2; p3; NA; unknown.'},
#  'qere': {'description': '✅ word pointed-transliterated masoretic reading correction ('},
#  'qere_utf8': {'description': '✅ word pointed-Hebrew masoretic reading correction ('},
#  'rela': {'description': '✅ linguistic relation between clause/(sub)phrase(atom) (ADJ; MOD; ATR; ...'},
#  'sp': {'description': '✅ part-of-speech (art; verb; subs; nmpr, ...'},
#  'st': {'description': '✅ state of a noun (a (absolute); c (construct); e (emphatic).'},
#  'tab': {'description': '✅ clause atom: its level in the linguistic embedding ('},
#  'txt': {'description': '✅ text type of clause and surrounding (repetion of ? N D Q as in feature domain'},
#  'typ': {'description': '✅ clause/phrase(atom) type (VP; NP; Ellp; Ptcp; WayX'},
#  'uvf': {'description': '✅ univalent final consonant consonantal-transliterated (absent; N; J; ...'},
#  'vbe': {'description': '✅ verbal ending consonantal-transliterated (n/a; W; ...'},
#  'vbs': {'description': '✅ root formation consonantal-transliterated (absent; n/a; H; ...'},
#  'verse': {'description': '✅ verse number ('},
#  'vs': {'description': '✅ verbal stem (qal; piel; hif; apel; pael'},
#  'vt': {'description': '✅ verbal tense (perf; impv; wayq; infc'}}

# %%
oText = {
    "": {
        "": """
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
@fmt:text-orig-full={g_word_utf8}{g_suffix_utf8}
""",
    },
    "_temp": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "2021": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "2017": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "2016": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "4b": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-full-ketiv={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word} 
@fmt:text-trans-full-ketiv={g_word} 
@fmt:text-trans-plain={g_cons} 
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "4": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-full-ketiv={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word} 
@fmt:text-trans-full-ketiv={g_word} 
@fmt:text-trans-plain={g_cons} 
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "3": """
@fmt:lex-orig-full={graphical_lexeme_utf8} 
@fmt:lex-orig-plain={lexeme_utf8} 
@fmt:lex-trans-full={graphical_lexeme} 
@fmt:lex-trans-plain={lexeme} 
@fmt:text-orig-full={text}{suffix}
@fmt:text-orig-plain={surface_consonants_utf8}{suffix}
@fmt:text-trans-full={graphical_word} 
@fmt:text-trans-plain={surface_consonants} 
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
    "c": """
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
""",  # noqa W291
}

# %% [markdown]
# The next function selects the proper otext material, falling back on a default if nothing
# appropriate has been specified in `oText`.

# %%
thisOtext = oText.get(VERSION, oText[""])

# %%
if thisOtext is oText[""]:
    utils.caption(
        0, "WARNING: no otext feature info provided, using a meager default value"
    )
    otextInfo = {}
else:
    utils.caption(0, "INFO: otext feature information found")
    otextInfo = dict(
        line[1:].split("=", 1) for line in thisOtext.strip("\n").split("\n")
    )
    for x in sorted(otextInfo.items()):
        utils.caption(0, '\t{:<20} = "{}"'.format(*x))
# Out:
# |       0.00s INFO: otext feature information found
# |       0.00s 	fmt:lex-orig-full    = "{g_lex_utf8} "
# |       0.00s 	fmt:lex-orig-plain   = "{lex_utf8} "
# |       0.00s 	fmt:lex-trans-full   = "{g_lex} "
# |       0.00s 	fmt:lex-trans-plain  = "{lex} "
# |       0.00s 	fmt:text-orig-full   = "{g_word_utf8}{trailer_utf8}"
# |       0.00s 	fmt:text-orig-plain  = "{g_cons_utf8}{trailer_utf8}"
# |       0.00s 	fmt:text-trans-full  = "{g_word}{trailer}"
# |       0.00s 	fmt:text-trans-plain = "{g_cons}{trailer}"
# |       0.00s 	sectionFeatures      = "book,chapter,verse"
# |       0.01s 	sectionTypes         = "book,chapter,verse"

# %% [markdown]
# # Overview
#
# The program has several stages:
#
# 1. **prepare** the source (utils.bunzip if needed)
# 1. **convert** convert the MQL file into a text-fabric dataset
# 1. **differences** (informational)
# 1. **deliver** the TF data at its destination directory
# 1. **compile** all TF features to binary format

# %% [markdown]
# # Prepare
#
# Check the source, utils.bunzip it if needed, empty the result directory.

# %%
if not os.path.exists(thisTempSource):
    os.makedirs(thisTempSource)

# %%
utils.caption(0, "bunzipping {} ...".format(mqlzFile))
utils.bunzip(mqlzFile, mqlFile)
utils.caption(0, "Done")
# Out:
# |       3.13s bunzipping /Users/werk/github/etcbc/bhsa/source/2021/bhsa.mql.bz2 ...
# |       3.13s 	NOTE: Using existing unzipped file which is newer than bzipped one
# |       3.13s Done

# %%
if os.path.exists(thisTempTf):
    rmtree(thisTempTf)
os.makedirs(thisTempTf)

# %% [markdown]
# # MQL to Text-Fabric
# Transform the collected information in feature-like data-structures, and write it all
# out to `.tf` files.

# %%
TF = Fabric(locations=thisTempTf, silent=SCRIPT)
# Out:
# This is Text-Fabric 9.1.6
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 0 features found and 0 ignored
#   0.00s Warp feature "otype" not found in
# ~/github/etcbc/bhsa/_temp/2021/tf/
#   0.00s Warp feature "oslots" not found in
# ~/github/etcbc/bhsa/_temp/2021/tf/
#   0.00s Warp feature "otext" not found. Working without Text-API

# %%
TF.importMQL(mqlFile, slotType=slotType, otext=otextInfo, meta=featureMetaData)
# Out:
#   0.00s Parsing mql source ...
#   0.00s 		enum boolean_t
#   0.00s 		enum phrase_determination_t
#   0.00s 		enum language_t
#   0.00s 		enum book_name_t
#   0.00s 		enum lexical_set_t
#   0.00s 		enum verbal_stem_t
#   0.00s 		enum verbal_tense_t
#   0.00s 		enum person_t
#   0.01s 		enum number_t
#   0.01s 		enum gender_t
#   0.01s 		enum state_t
#   0.01s 		enum part_of_speech_t
#   0.01s 		enum phrase_type_t
#   0.01s 		enum phrase_atom_relation_t
#   0.01s 		enum phrase_relation_t
#   0.01s 		enum phrase_atom_unit_distance_to_mother_t
#   0.01s 		enum subphrase_relation_t
#   0.01s 		enum subphrase_mother_object_type_t
#   0.01s 		enum phrase_function_t
#   0.01s 		enum clause_atom_type_t
#   0.01s 		enum clause_type_t
#   0.01s 		enum clause_kind_t
#   0.01s 		enum clause_constituent_relation_t
#   0.01s 		enum clause_constituent_mother_object_type_t
#   0.01s 		enum clause_constituent_unit_distance_to_mother_t
#   0.01s 		otype word
#   0.01s 			feature number (int) =def= 0 : node
#   0.02s 			feature lexeme_count (int) =def= 0 : node
#   0.02s 			feature kq_hybrid (str) =def=  : node
#   0.02s 			feature qere_utf8 (str) =def=  : node
#   0.02s 			feature qere (str) =def=  : node
#   0.02s 			feature kq_hybrid_utf8 (str) =def=  : node
#   0.02s 			feature g_word (str) =def=  : node
#   0.02s 			feature g_word_utf8 (str) =def=  : node
#   0.02s 			feature g_cons_utf8 (str) =def=  : node
#   0.02s 			feature g_cons (str) =def=  : node
#   0.02s 			feature g_suffix (str) =def=  : node
#   0.02s 			feature g_suffix_utf8 (str) =def=  : node
#   0.02s 			feature g_pfm (str) =def=  : node
#   0.02s 			feature g_pfm_utf8 (str) =def=  : node
#   0.02s 			feature g_vbs (str) =def=  : node
#   0.02s 			feature g_vbs_utf8 (str) =def=  : node
#   0.02s 			feature lex (str) =def=  : node
#   0.02s 			feature lex_utf8 (str) =def=  : node
#   0.02s 			feature g_lex (str) =def=  : node
#   0.02s 			feature g_lex_utf8 (str) =def=  : node
#   0.02s 			feature g_voc_lex (str) =def=  : node
#   0.02s 			feature g_voc_lex_utf8 (str) =def=  : node
#   0.02s 			feature g_prs_utf8 (str) =def=  : node
#   0.03s 			feature g_prs (str) =def=  : node
#   0.03s 			feature g_vbe (str) =def=  : node
#   0.03s 			feature g_uvf_utf8 (str) =def=  : node
#   0.03s 			feature g_uvf (str) =def=  : node
#   0.03s 			feature g_vbe_utf8 (str) =def=  : node
#   0.03s 			feature g_nme (str) =def=  : node
#   0.03s 			feature g_nme_utf8 (str) =def=  : node
#   0.03s 			feature nme (str) =def=  : node
#   0.03s 			feature distributional_parent (str) =def= 0 : edge
#   0.03s 			feature functional_parent (str) =def= 0 : edge
#   0.03s 			feature prs (str) =def=  : node
#   0.03s 			feature vbe (str) =def=  : node
#   0.03s 			feature vbs (str) =def=  : node
#   0.03s 			feature pfm (str) =def=  : node
#   0.03s 			feature uvf (str) =def=  : node
#   0.03s 			feature language (str) =def= Hebrew : node
#   0.03s 			feature ls (str) =def= none : node
#   0.03s 			feature vs (str) =def= NA : node
#   0.03s 			feature vt (str) =def= NA : node
#   0.03s 			feature prs_ps (str) =def= NA : node
#   0.03s 			feature ps (str) =def= NA : node
#   0.03s 			feature suffix_person (str) =def= NA : node
#   0.03s 			feature prs_nu (str) =def= NA : node
#   0.03s 			feature nu (str) =def= NA : node
#   0.04s 			feature suffix_number (str) =def= NA : node
#   0.04s 			feature gn (str) =def= NA : node
#   0.04s 			feature suffix_gender (str) =def= NA : node
#   0.04s 			feature prs_gn (str) =def= NA : node
#   0.04s 			feature st (str) =def= NA : node
#   0.04s 			feature sp (str) =def= art : node
#   0.04s 			feature pdp (str) =def= art : node
#   0.04s 		otype clause_atom
#   0.04s 			feature tab (int) =def= 0 : node
#   0.04s 			feature code (int) =def= 0 : node
#   0.04s 			feature dist (int) =def= 0 : node
#   0.04s 			feature number (int) =def= 0 : node
#   0.04s 			feature distributional_parent (str) =def= 0 : edge
#   0.04s 			feature mother (str) =def= 0 : edge
#   0.04s 			feature functional_parent (str) =def= 0 : edge
#   0.04s 			feature is_root (str) =def= false : node
#   0.04s 			feature typ (str) =def= Unkn : node
#   0.04s 		otype sentence_atom
#   0.04s 			feature number (int) =def= 0 : node
#   0.04s 			feature functional_parent (str) =def= 0 : edge
#   0.04s 		otype subphrase
#   0.04s 			feature dist (int) =def= 0 : node
#   0.04s 			feature mother (str) =def= 0 : edge
#   0.05s 			feature rela (str) =def= NA : node
#   0.05s 			feature mother_object_type (str) =def= NA : node
#   0.05s 		otype phrase
#   0.05s 			feature dist (int) =def= 0 : node
#   0.05s 			feature number (int) =def= 0 : node
#   0.05s 			feature functional_parent (str) =def= 0 : edge
#   0.05s 			feature mother (str) =def= 0 : edge
#   0.05s 			feature det (str) =def= NA : node
#   0.05s 			feature typ (str) =def= VP : node
#   0.05s 			feature rela (str) =def= NA : node
#   0.05s 			feature dist_unit (str) =def= clause_atoms : node
#   0.05s 			feature function (str) =def= Unkn : node
#   0.05s 		otype sentence
#   0.05s 			feature number (int) =def= 0 : node
#   0.05s 		otype chapter
#   0.05s 			feature chapter (int) =def= 0 : node
#   0.05s 			feature book (str) =def= Genesis : node
#   0.05s 		otype book
#   0.05s 			feature book (str) =def= Genesis : node
#   0.05s 		otype clause
#   0.06s 			feature dist (int) =def= 0 : node
#   0.06s 			feature number (int) =def= 0 : node
#   0.06s 			feature domain (str) =def=  : node
#   0.06s 			feature mother (str) =def= 0 : edge
#   0.06s 			feature functional_parent (str) =def= 0 : edge
#   0.06s 			feature txt (str) =def=  : node
#   0.06s 			feature typ (str) =def= Unkn : node
#   0.06s 			feature kind (str) =def= unknown : node
#   0.06s 			feature rela (str) =def= NA : node
#   0.06s 			feature mother_object_type (str) =def= clause : node
#   0.06s 			feature dist_unit (str) =def= clause_atoms : node
#   0.06s 		otype half_verse
#   0.06s 			feature label (str) =def=  : node
#   0.06s 		otype verse
#   0.06s 			feature verse (int) =def= 0 : node
#   0.06s 			feature chapter (int) =def= 0 : node
#   0.06s 			feature label (str) =def=  : node
#   0.06s 			feature book (str) =def= Genesis : node
#   0.06s 		otype phrase_atom
#   0.06s 			feature number (int) =def= 0 : node
#   0.06s 			feature dist (int) =def= 0 : node
#   0.06s 			feature distributional_parent (str) =def= 0 : edge
#   0.06s 			feature mother (str) =def= 0 : edge
#   0.06s 			feature functional_parent (str) =def= 0 : edge
#   0.06s 			feature det (str) =def= NA : node
#   0.07s 			feature typ (str) =def= VP : node
#   0.07s 			feature rela (str) =def= NA : node
#   0.07s 			feature dist_unit (str) =def= clause_atoms : node
#   0.07s 		objects in word
#   3.23s 	line   1000000
#   6.42s 	line   2000000
#   9.35s 		objects in word
#   9.66s 	line   3000000
#     13s 	line   4000000
#     16s 	line   5000000
#     18s 		objects in word
#     19s 	line   6000000
#     22s 	line   7000000
#     25s 	line   8000000
#     27s 		objects in word
#     27s 	line   9000000
#     30s 	line  10000000
#     33s 	line  11000000
#     35s 		objects in word
#     36s 	line  12000000
#     39s 	line  13000000
#     42s 	line  14000000
#     44s 		objects in word
#     45s 	line  15000000
#     49s 	line  16000000
#     52s 	line  17000000
#     53s 		objects in word
#     55s 	line  18000000
#     58s 	line  19000000
#  1m 01s 	line  20000000
#  1m 02s 		objects in word
#  1m 04s 	line  21000000
#  1m 07s 	line  22000000
#  1m 10s 	line  23000000
#  1m 11s 		objects in word
#  1m 13s 	line  24000000
#  1m 15s 		objects in clause_atom
#  1m 16s 	line  25000000
#  1m 17s 		objects in clause_atom
#  1m 18s 		objects in sentence_atom
#  1m 18s 	line  26000000
#  1m 19s 		objects in sentence_atom
#  1m 19s 		objects in subphrase
#  1m 20s 		objects in subphrase
#  1m 20s 	line  27000000
#  1m 20s 		objects in subphrase
#  1m 20s 		objects in phrase
#  1m 22s 		objects in phrase
#  1m 23s 	line  28000000
#  1m 23s 		objects in phrase
#  1m 24s 	line  29000000
#  1m 25s 		objects in phrase
#  1m 26s 		objects in phrase
#  1m 27s 	line  30000000
#  1m 28s 		objects in phrase
#  1m 28s 		objects in sentence
#  1m 28s 		objects in sentence
#  1m 28s 		objects in chapter
#  1m 28s 		objects in book
#  1m 28s 		objects in clause
#  1m 29s 	line  31000000
#  1m 30s 		objects in clause
#  1m 30s 	line  32000000
#  1m 31s 		objects in half_verse
#  1m 32s 		objects in verse
#  1m 33s 		objects in phrase_atom
#  1m 33s 	line  33000000
#  1m 34s 		objects in phrase_atom
#  1m 35s 		objects in phrase_atom
#  1m 35s 	line  34000000
#  1m 36s 		objects in phrase_atom
#  1m 37s 	line  35000000
#  1m 37s 		objects in phrase_atom
#  1m 38s 		objects in phrase_atom
#  1m 40s 	line  36000000
#  1m 40s 36047659 lines parsed
#  1m 40s 426590 objects of type word
#  1m 40s 90704 objects of type clause_atom
#  1m 40s 64514 objects of type sentence_atom
#  1m 40s 113850 objects of type subphrase
#  1m 40s 253203 objects of type phrase
#  1m 40s 63717 objects of type sentence
#  1m 40s 929 objects of type chapter
#  1m 40s 39 objects of type book
#  1m 40s 88131 objects of type clause
#  1m 40s 45179 objects of type half_verse
#  1m 40s 23213 objects of type verse
#  1m 40s 267532 objects of type phrase_atom
#  1m 40s Making TF data ...
# {'': {'dataset': 'BHSA', 'version': '2021', 'datasetName': 'Biblia Hebraica Stuttgartensia Amstelodamensis', 'author': 'Eep Talstra Centre for Bible and Computer', 'encoders': 'Constantijn Sikkel (QDF), Ulrik Petersen (MQL) and Dirk Roorda (TF)', 'website': 'https://shebanq.ancient-data.org', 'email': 'shebanq@ancient-data.org'}, 'g_suffix': {'description': 'interword material pointed-transliterated (& 00 05 00_P ...)'}, 'g_cons_utf8': {'description': 'word consonantal-Hebrew (ב ראשׁית ברא אלהים)'}, 'prs_ps': {'description': 'pronominal suffix person (p1; p2; p3; NA; unknown.)'}, 'g_nme_utf8': {'description': 'nominal ending pointed-Hebrew (ים ֶ֜ת  ֵ֜י)'}, 'ps': {'description': 'grammatical person (p1; p2; p3; NA; unknown.)'}, 'g_voc_lex_utf8': {'description': 'vocalized lexeme pointed-Hebrew (בְּ רֵאשִׁית ברא אֱלֹהִים)'}, 'g_vbs_utf8': {'description': 'root formation pointed-Hebrew (הַ)'}, 'g_pfm': {'description': 'preformative pointed-transliterated (!J.O! !J:! !J:! !J.A! ...)'}, 'lex_utf8': {'description': 'lexeme consonantal-Hebrew (ב ראשׁית֜ ברא אלהים֜)'}, 'g_prs_utf8': {'description': 'pronominal suffix pointed-Hebrew (ו ֵהוּ)'}, 'vt': {'description': 'verbal tense (perf; impv; wayq; infc)'}, 'pfm': {'description': 'preformative consonantal-transliterated (absent; n/a; J, ...)'}, 'g_voc_lex': {'description': 'vocalized lexeme pointed-transliterated (B.: R;>CIJT BR> >:ELOHIJM)'}, 'kq_hybrid': {'description': 'unclear, ketiv/qere related ()'}, 'prs_nu': {'description': 'pronominal suffix number (sg; du; pl; NA; unknown.)'}, 'g_suffix_utf8': {'description': 'interword material pointed-Hebrew (־ ׃)'}, 'ls': {'description': 'lexical set, subclassification of part-of-speech (card; ques; mult)'}, 'g_word_utf8': {'description': 'word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)'}, 'st': {'description': 'state of a noun (a (absolute); c (construct); e (emphatic).)'}, 'vbe': {'description': 'verbal ending consonantal-transliterated (n/a; W; ...)'}, 'lexeme_count': {'description': 'on words: the number of occurrences of its lexeme ()'}, 'number': {'description': 'sequence number of an object within its context ()'}, 'uvf': {'description': 'univalent final consonant consonantal-transliterated (absent; N; J; ...)'}, 'qere_utf8': {'description': 'word pointed-Hebrew masoretic reading correction ()'}, 'sp': {'description': 'part-of-speech (art; verb; subs; nmpr, ...)'}, 'pdp': {'description': 'phrase dependent part-of-speech (art; verb; subs; nmpr, ...)'}, 'vs': {'description': 'verbal stem (qal; piel; hif; apel; pael)'}, 'lex': {'description': 'lexeme consonantal-transliterated (B R>CJT/ BR>[ >LHJM/)'}, 'g_nme': {'description': 'nominal ending pointed-transliterated (/IJM /ET /;J ...)'}, 'gn': {'description': 'grammatical gender (m; f; NA; unknown.)'}, 'prs': {'description': 'pronominal suffix consonantal-transliterated (absent; n/a; W; ...)'}, 'g_cons': {'description': 'word consonantal-transliterated (B R>CJT BR> >LHJM ...)'}, 'g_prs': {'description': 'pronominal suffix pointed-transliterated (+OW +;HW ...)'}, 'g_pfm_utf8': {'description': 'preformative pointed-Hebrew (יְ יְ יַּ)'}, 'vbs': {'description': 'root formation consonantal-transliterated (absent; n/a; H; ...)'}, 'nme': {'description': 'nominal ending consonantal-transliterated (absent; n/a; JM, ...)'}, 'g_vbe': {'description': 'verbal ending pointed-transliterated ([W. ...)'}, 'g_lex_utf8': {'description': 'lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)'}, 'g_lex': {'description': 'lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)'}, 'g_vbs': {'description': 'root formation pointed-transliteratedeg (]] ]HA] ...)'}, 'qere': {'description': 'word pointed-transliterated masoretic reading correction ()'}, 'prs_gn': {'description': 'pronominal suffix gender (m; f; NA; unknown.)'}, 'g_uvf_utf8': {'description': 'univalent final consonant pointed-Hebrew (ֶ ָה)'}, 'nu': {'description': 'grammatical number (sg; du; pl; NA; unknown.)'}, 'g_vbe_utf8': {'descriptio ...
#  1m 40s Monad - idd mapping ...
#  1m 40s Removing holes in the monad sequence
#  1m 40s maxSlot=426590
#  1m 40s Node mapping and otype ...
#  1m 41s oslots ...
#  1m 43s metadata ...
#  1m 43s features ...
#  1m 43s 	features from words
#  1m 45s 	   100000 words
#  1m 47s 	   200000 words
#  1m 49s 	   300000 words
#  1m 53s 	   400000 words
#  1m 53s 	   426590 words
#  1m 53s 	features from books
#  1m 53s 	       39 books
#  1m 53s 	features from chapters
#  1m 53s 	      929 chapters
#  1m 53s 	features from clauses
#  1m 53s 	    88131 clauses
#  1m 53s 	features from clause_atoms
#  1m 54s 	    90704 clause_atoms
#  1m 54s 	features from half_verses
#  1m 54s 	    45179 half_verses
#  1m 54s 	features from phrases
#  1m 54s 	   100000 phrases
#  1m 55s 	   200000 phrases
#  1m 55s 	   253203 phrases
#  1m 55s 	features from phrase_atoms
#  1m 55s 	   100000 phrase_atoms
#  1m 58s 	   200000 phrase_atoms
#  1m 58s 	   267532 phrase_atoms
#  1m 58s 	features from sentences
#  1m 58s 	    63717 sentences
#  1m 58s 	features from sentence_atoms
#  1m 58s 	    64514 sentence_atoms
#  1m 58s 	features from subphrases
#  1m 58s 	   100000 subphrases
#  1m 58s 	   113850 subphrases
#  1m 58s 	features from verses
#  1m 58s 	    23213 verses
#   0.00s Exporting 70 node and 4 edge and 1 config features to ~/github/etcbc/bhsa/_temp/2021/tf:
#   0.00s VALIDATING oslots feature
#   0.10s VALIDATING oslots feature
#   0.10s maxSlot=     426590
#   0.10s maxNode=    1437601
#   0.22s OK: oslots is valid
#    |     0.02s T book                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.03s T chapter              to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.08s T code                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.46s T det                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.62s T dist                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.54s T dist_unit            to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.07s T domain               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.22s T function             to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.36s T g_cons               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T g_cons_utf8          to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.37s T g_lex                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.40s T g_lex_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.32s T g_nme                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.36s T g_nme_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.31s T g_pfm                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.32s T g_pfm_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T g_prs                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.31s T g_prs_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.33s T g_suffix             to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.34s T g_suffix_utf8        to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T g_uvf                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T g_uvf_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.33s T g_vbe                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.31s T g_vbe_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T g_vbs                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T g_vbs_utf8           to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T g_voc_lex            to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.41s T g_voc_lex_utf8       to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T g_word               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.40s T g_word_utf8          to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.36s T gn                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.08s T is_root              to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.08s T kind                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.30s T kq_hybrid            to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.31s T kq_hybrid_utf8       to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.06s T label                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T language             to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T lex                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.40s T lex_utf8             to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T lexeme_count         to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T ls                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.17s T mother_object_type   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.34s T nme                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.37s T nu                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     1.03s T number               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.32s T otype                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T pdp                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.37s T pfm                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.41s T prs                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T prs_gn               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T prs_nu               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T prs_ps               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T ps                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.32s T qere                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.31s T qere_utf8            to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.62s T rela                 to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T sp                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.36s T st                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.38s T suffix_gender        to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T suffix_number        to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T suffix_person        to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.08s T tab                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.08s T txt                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.60s T typ                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T uvf                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.37s T vbe                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.42s T vbs                  to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.02s T verse                to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T vs                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.39s T vt                   to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     1.23s T distributional_parent to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     1.86s T functional_parent    to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.32s T mother               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     1.93s T oslots               to ~/github/etcbc/bhsa/_temp/2021/tf
#    |     0.00s M otext                to ~/github/etcbc/bhsa/_temp/2021/tf
#     29s Exported 70 node features and 4 edge features and 1 config features to ~/github/etcbc/bhsa/_temp/2021/tf

# %% [markdown]
# # Rename features
# We rename the features mentioned in the RENAME dictionary.

# %%
if RENAME is None:
    utils.caption(4, "Rename features: nothing to do")
else:
    utils.caption(4, "Renaming {} features in {}".format(len(RENAME), thisTempTf))
    for (srcFeature, dstFeature) in RENAME:
        srcPath = "{}/{}.tf".format(thisTempTf, srcFeature)
        dstPath = "{}/{}.tf".format(thisTempTf, dstFeature)
        if os.path.exists(srcPath):
            os.rename(srcPath, dstPath)
            utils.caption(0, "\trenamed {} to {}".format(srcFeature, dstFeature))
        else:
            utils.caption(0, "\tsource feature {} does not exist.".format(srcFeature))
            utils.caption(
                0, "\tdestination feature {} will not be created.".format(dstFeature)
            )
# Out:
# ..............................................................................................
# .     18m 27s Renaming 2 features in /Users/werk/github/etcbc/bhsa/_temp/2021/tf             .
# ..............................................................................................
# |     18m 27s 	renamed g_suffix to trailer
# |     18m 27s 	renamed g_suffix_utf8 to trailer_utf8

# %% [markdown]
# # Diffs
#
# Check differences with previous versions.
#
# The new dataset has been created in a temporary directory,
# and has not yet been copied to its destination.
#
# Here is your opportunity to compare the newly created features with the older features.
# You expect some differences in some features.
#
# We check the differences between the previous version of the features and what has been generated.
# We list features that will be added and deleted and changed.
# For each changed feature we show the first line where the new feature differs from the old one.
# We ignore changes in the metadata, because the timestamp in the metadata will always change.

# %%
utils.checkDiffs(thisTempTf, thisTf)
# Out:
# ..............................................................................................
# .     18m 32s Check differences with previous version                                        .
# ..............................................................................................
# |     18m 32s 	2 features to add
# |     18m 32s 		g_voc_lex
# |     18m 32s 		g_voc_lex_utf8
# |     18m 32s 	43 features to delete
# |     18m 32s 		book@am
# |     18m 32s 		book@ar
# |     18m 32s 		book@bn
# |     18m 32s 		book@da
# |     18m 32s 		book@de
# |     18m 32s 		book@el
# |     18m 32s 		book@en
# |     18m 32s 		book@es
# |     18m 32s 		book@fa
# |     18m 32s 		book@fr
# |     18m 32s 		book@he
# |     18m 32s 		book@hi
# |     18m 32s 		book@id
# |     18m 32s 		book@ja
# |     18m 32s 		book@ko
# |     18m 32s 		book@la
# |     18m 32s 		book@nl
# |     18m 32s 		book@pa
# |     18m 32s 		book@pt
# |     18m 32s 		book@ru
# |     18m 32s 		book@sw
# |     18m 32s 		book@syc
# |     18m 32s 		book@tr
# |     18m 32s 		book@ur
# |     18m 32s 		book@yo
# |     18m 32s 		book@zh
# |     18m 32s 		freq_lex
# |     18m 32s 		freq_occ
# |     18m 32s 		gloss
# |     18m 32s 		instruction
# |     18m 32s 		languageISO
# |     18m 32s 		lex0
# |     18m 32s 		nametype
# |     18m 32s 		omap@2017-2021
# |     18m 32s 		omap@c-2021
# |     18m 32s 		pargr
# |     18m 32s 		qere_trailer
# |     18m 32s 		qere_trailer_utf8
# |     18m 32s 		rank_lex
# |     18m 32s 		rank_occ
# |     18m 32s 		root
# |     18m 32s 		voc_lex
# |     18m 32s 		voc_lex_utf8
# |     18m 32s 	73 features in common
# |     18m 32s book                      ... no changes
# |     18m 32s chapter                   ... no changes
# |     18m 33s code                      ... no changes
# |     18m 33s det                       ... no changes
# |     18m 33s dist                      ... no changes
# |     18m 33s dist_unit                 ... no changes
# |     18m 34s distributional_parent     ... no changes
# |     18m 34s domain                    ... no changes
# |     18m 34s function                  ... no changes
# |     18m 34s functional_parent         ... no changes
# |     18m 35s g_cons                    ... no changes
# |     18m 35s g_cons_utf8               ... no changes
# |     18m 35s g_lex                     ... no changes
# |     18m 35s g_lex_utf8                ... no changes
# |     18m 36s g_nme                     ... no changes
# |     18m 36s g_nme_utf8                ... no changes
# |     18m 36s g_pfm                     ... no changes
# |     18m 36s g_pfm_utf8                ... no changes
# |     18m 36s g_prs                     ... no changes
# |     18m 37s g_prs_utf8                ... no changes
# |     18m 37s g_uvf                     ... no changes
# |     18m 37s g_uvf_utf8                ... no changes
# |     18m 37s g_vbe                     ... no changes
# |     18m 37s g_vbe_utf8                ... no changes
# |     18m 38s g_vbs                     ... no changes
# |     18m 38s g_vbs_utf8                ... no changes
# |     18m 38s g_word                    ... no changes
# |     18m 38s g_word_utf8               ... no changes
# |     18m 38s gn                        ... no changes
# |     18m 39s is_root                   ... no changes
# |     18m 39s kind                      ... no changes
# |     18m 39s kq_hybrid                 ... no changes
# |     18m 39s kq_hybrid_utf8            ... no changes
# |     18m 39s label                     ... no changes
# |     18m 39s language                  ... differences after the metadata
# |     18m 39s 	line 426592 OLD -->1437602	Hebrew<--
# |     18m 39s 	line 426592 NEW --><empty><--
# |     18m 39s 	line 426593 OLD -->Hebrew<--
# |     18m 39s 	line 426593 NEW --><empty><--
# |     18m 39s 	line 426594 OLD -->Hebrew<--
# |     18m 39s 	line 426594 NEW --><empty><--
# |     18m 39s 	line 426595 OLD -->Hebrew<--
# |     18m 39s 	line 426595 NEW --><empty><--
#
# |     18m 39s lex                       ... differences after the metadata
# |     18m 40s 	line 426592 OLD -->1437602	B<--
# |     18m 40s 	line 426592 NEW --><empty><--
# |     18m 40s 	line 426593 OLD -->R>CJT/<--
# |     18m 40s 	line 426593 NEW --><empty><--
# |     18m 40s 	line 426594 OLD -->BR>[<--
# |     18m 40s 	line 426594 NEW --><empty><--
# |     18m 40s 	line 426595 OLD -->>LHJM/<--
# |     18m 40s 	line 426595 NEW --><empty><--
#
# |     18m 40s lex_utf8                  ... differences after the metadata
# |     18m 40s 	line      3 OLD -->ראשׁית<--
# |     18m 40s 	line      3 NEW -->ראשׁית֜<--
# |     18m 40s 	line      5 OLD -->אלהים<--
# |     18m 40s 	line      5 NEW -->אלהים֜<--
# |     18m 40s 	line      8 OLD -->שׁמים<--
# |     18m 40s 	line      8 NEW -->שׁמים֜<--
# |     18m 40s 	line     12 OLD -->ארץ<--
# |     18m 40s 	line     12 NEW -->ארץ֜<--
#
# |     18m 40s lexeme_count              ... no changes
# |     18m 40s ls                        ... differences after the metadata
# |     18m 40s 	line 426592 OLD -->1437611	vbcp<--
# |     18m 40s 	line 426592 NEW --><empty><--
# |     18m 40s 	line 426593 OLD -->1437621	quot<--
# |     18m 40s 	line 426593 NEW --><empty><--
# |     18m 40s 	line 426594 OLD -->1437627	ppre<--
# |     18m 40s 	line 426594 NEW --><empty><--
# |     18m 40s 	line 426595 OLD -->1437630	padv<--
# |     18m 40s 	line 426595 NEW --><empty><--
#
# |     18m 40s mother                    ... no changes
# |     18m 40s mother_object_type        ... no changes
# |     18m 40s nme                       ... no changes
# |     18m 40s nu                        ... no changes
# |     18m 41s number                    ... no changes
# |     18m 41s oslots                    ... differences after the metadata
# |     18m 42s 	line 1011013 OLD -->1,84,197,220,241,270,318,330,334,428,435 ...<--
# |     18m 42s 	line 1011013 NEW --><empty><--
# |     18m 42s 	line 1011014 OLD -->2,4662,27812,41332,48285,53078,66102,796 ...<--
# |     18m 42s 	line 1011014 NEW --><empty><--
# |     18m 42s 	line 1011015 OLD -->3,381,535,545,550,724,736,2126,2137,2148 ...<--
# |     18m 42s 	line 1011015 NEW --><empty><--
# |     18m 42s 	line 1011016 OLD -->4,26,34,42,50,60,81,97,127,142,162,176,1 ...<--
# |     18m 42s 	line 1011016 NEW --><empty><--
#
# |     18m 42s otext                     ... differences
# |     18m 42s 	line      5 OLD -->@dateWritten=2021-11-30T15:28:55Z<--
# |     18m 42s 	line      5 NEW -->@email=shebanq@ancient-data.org<--
# |     18m 42s 	line      6 OLD -->@email=shebanq@ancient-data.org<--
# |     18m 42s 	line      6 NEW -->@encoders=Constantijn Sikkel (QDF), Ulri ...<--
# |     18m 42s 	line      7 OLD -->@encoders=Constantijn Sikkel (QDF), Ulri ...<--
# |     18m 42s 	line      7 NEW -->@fmt:lex-orig-full={g_lex_utf8} <--
# |     18m 42s 	line      8 OLD -->@fmt:lex-default={voc_lex_utf8} <--
# |     18m 42s 	line      8 NEW -->@fmt:lex-orig-plain={lex_utf8} <--
#
# |     18m 42s otype                     ... differences after the metadata
# |     18m 42s 	line     14 OLD -->1437602-1446831	lex<--
# |     18m 42s 	line     14 NEW --><empty><--
#
# |     18m 42s pdp                       ... no changes
# |     18m 42s pfm                       ... no changes
# |     18m 42s prs                       ... no changes
# |     18m 42s prs_gn                    ... no changes
# |     18m 43s prs_nu                    ... no changes
# |     18m 43s prs_ps                    ... no changes
# |     18m 43s ps                        ... no changes
# |     18m 43s qere                      ... differences after the metadata
# |     18m 43s 	line      2 OLD -->3897	HAJ:Y;74><--
# |     18m 43s 	line      2 NEW --><--
# |     18m 43s 	line      3 OLD -->4420	>@H:@LO75W<--
# |     18m 43s 	line      3 NEW --><--
# |     18m 43s 	line      4 OLD -->5645	>@H:@LO92W<--
# |     18m 43s 	line      4 NEW --><--
# |     18m 43s 	line      5 OLD -->5912	>@95H:@LOW03<--
# |     18m 43s 	line      5 NEW --><--
#
# |     18m 43s qere_utf8                 ... differences after the metadata
# |     18m 43s 	line      2 OLD -->3897	הַיְצֵ֣א<--
# |     18m 43s 	line      2 NEW --><--
# |     18m 43s 	line      3 OLD -->4420	אָהֳלֹֽו<--
# |     18m 43s 	line      3 NEW --><--
# |     18m 43s 	line      4 OLD -->5645	אָהֳלֹ֑ו<--
# |     18m 43s 	line      4 NEW --><--
# |     18m 43s 	line      5 OLD -->5912	אָֽהֳלֹו֙<--
# |     18m 43s 	line      5 NEW --><--
#
# |     18m 43s rela                      ... no changes
# |     18m 44s sp                        ... differences after the metadata
# |     18m 44s 	line 426592 OLD -->1437602	prep<--
# |     18m 44s 	line 426592 NEW --><empty><--
# |     18m 44s 	line 426593 OLD -->subs<--
# |     18m 44s 	line 426593 NEW --><empty><--
# |     18m 44s 	line 426594 OLD -->verb<--
# |     18m 44s 	line 426594 NEW --><empty><--
# |     18m 44s 	line 426595 OLD -->subs<--
# |     18m 44s 	line 426595 NEW --><empty><--
#
# |     18m 44s st                        ... no changes
# |     18m 44s suffix_gender             ... no changes
# |     18m 44s suffix_number             ... no changes
# |     18m 45s suffix_person             ... no changes
# |     18m 45s tab                       ... no changes
# |     18m 45s trailer                   ... no changes
# |     18m 45s trailer_utf8              ... no changes
# |     18m 45s txt                       ... no changes
# |     18m 45s typ                       ... no changes
# |     18m 46s uvf                       ... no changes
# |     18m 46s vbe                       ... no changes
# |     18m 46s vbs                       ... no changes
# |     18m 46s verse                     ... no changes
# |     18m 46s vs                        ... no changes
# |     18m 46s vt                        ... no changes
# |     18m 47s Done

# %% [markdown]
# # Deliver
#
# Copy the new TF dataset from the temporary location where it has been created to its final destination.

# %%
utils.deliverDataset(thisTempTf, thisTf)
# Out:
# ..............................................................................................
# .     19m 22s Deliver data set to /Users/werk/github/etcbc/bhsa/tf/2021                      .
# ..............................................................................................

# %% [markdown]
# # Compile TF
#
# Just to see whether everything loads and the pre-computing of extra information works out.
# Moreover, if you want to work with these features, then the pre-computing has already been done, and everything is quicker in subsequent runs.
#
# We issue load statement to trigger the pre-computing of extra data.
# Note that all features specified text formats in the `otext` config feature,
# will be loaded, as well as the features for sections.
#
# At that point we have access to the full list of features.
# We grab them and are going to load them all!

# %%
utils.caption(4, "Load and compile standard TF features")
TF = Fabric(locations=thisTf, modules=[""])
api = TF.load("")
# Out:
# ..............................................................................................
# .     19m 26s Load and compile standard TF features                                          .
# ..............................................................................................
# This is Text-Fabric 9.1.6
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 75 features found and 0 ignored
#   0.00s loading features ...
#    |     0.42s T otype                from ~/github/etcbc/bhsa/tf/2021
#    |     7.31s T oslots               from ~/github/etcbc/bhsa/tf/2021
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.90s T g_word_utf8          from ~/github/etcbc/bhsa/tf/2021
#    |     0.83s T g_lex_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.03s T verse                from ~/github/etcbc/bhsa/tf/2021
#    |     0.81s T g_cons_utf8          from ~/github/etcbc/bhsa/tf/2021
#    |     0.73s T g_lex                from ~/github/etcbc/bhsa/tf/2021
#    |     0.59s T trailer              from ~/github/etcbc/bhsa/tf/2021
#    |     0.04s T book                 from ~/github/etcbc/bhsa/tf/2021
#    |     0.72s T lex                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.61s T trailer_utf8         from ~/github/etcbc/bhsa/tf/2021
#    |     0.81s T lex_utf8             from ~/github/etcbc/bhsa/tf/2021
#    |     0.03s T chapter              from ~/github/etcbc/bhsa/tf/2021
#    |     0.73s T g_cons               from ~/github/etcbc/bhsa/tf/2021
#    |     0.81s T g_word               from ~/github/etcbc/bhsa/tf/2021
#    |      |     0.52s C __levels__           from otype, oslots, otext
#    |      |       11s C __order__            from otype, oslots, __levels__
#    |      |     0.60s C __rank__             from otype, __order__
#    |      |       13s C __levUp__            from otype, oslots, __rank__
#    |      |     8.44s C __levDown__          from otype, __levUp__, __rank__
#    |      |     3.97s C __boundary__         from otype, oslots, __rank__
#    |      |     0.06s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#     53s All features loaded/computed - for details use TF.isLoaded()

# %%
utils.caption(4, "Load and compile all other TF features")
allFeatures = TF.explore(silent=False, show=True)
loadableFeatures = allFeatures["nodes"] + allFeatures["edges"]
api = TF.load(loadableFeatures)
api.makeAvailableIn(globals())
# Out:
# ..............................................................................................
# .     20m 19s Load and compile all other TF features                                         .
# ..............................................................................................
#    |     0.00s Feature overview: 70 for nodes; 4 for edges; 1 configs; 8 computed
#   0.00s loading features ...
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.11s T code                 from ~/github/etcbc/bhsa/tf/2021
#    |     0.83s T det                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.89s T dist                 from ~/github/etcbc/bhsa/tf/2021
#    |     1.00s T dist_unit            from ~/github/etcbc/bhsa/tf/2021
#    |     2.68s T distributional_parent from ~/github/etcbc/bhsa/tf/2021
#    |     0.14s T domain               from ~/github/etcbc/bhsa/tf/2021
#    |     0.43s T function             from ~/github/etcbc/bhsa/tf/2021
#    |     3.75s T functional_parent    from ~/github/etcbc/bhsa/tf/2021
#    |     0.53s T g_nme                from ~/github/etcbc/bhsa/tf/2021
#    |     0.57s T g_nme_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.44s T g_pfm                from ~/github/etcbc/bhsa/tf/2021
#    |     0.44s T g_pfm_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.44s T g_prs                from ~/github/etcbc/bhsa/tf/2021
#    |     0.44s T g_prs_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.39s T g_uvf                from ~/github/etcbc/bhsa/tf/2021
#    |     0.38s T g_uvf_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.45s T g_vbe                from ~/github/etcbc/bhsa/tf/2021
#    |     0.41s T g_vbe_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.40s T g_vbs                from ~/github/etcbc/bhsa/tf/2021
#    |     0.40s T g_vbs_utf8           from ~/github/etcbc/bhsa/tf/2021
#    |     0.74s T g_voc_lex            from ~/github/etcbc/bhsa/tf/2021
#    |     0.83s T g_voc_lex_utf8       from ~/github/etcbc/bhsa/tf/2021
#    |     0.68s T gn                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.14s T is_root              from ~/github/etcbc/bhsa/tf/2021
#    |     0.14s T kind                 from ~/github/etcbc/bhsa/tf/2021
#    |     0.41s T kq_hybrid            from ~/github/etcbc/bhsa/tf/2021
#    |     0.40s T kq_hybrid_utf8       from ~/github/etcbc/bhsa/tf/2021
#    |     0.11s T label                from ~/github/etcbc/bhsa/tf/2021
#    |     0.68s T language             from ~/github/etcbc/bhsa/tf/2021
#    |     0.50s T lexeme_count         from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T ls                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.57s T mother               from ~/github/etcbc/bhsa/tf/2021
#    |     0.36s T mother_object_type   from ~/github/etcbc/bhsa/tf/2021
#    |     0.61s T nme                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T nu                   from ~/github/etcbc/bhsa/tf/2021
#    |     1.43s T number               from ~/github/etcbc/bhsa/tf/2021
#    |     0.71s T pdp                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T pfm                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.71s T prs                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T prs_gn               from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T prs_nu               from ~/github/etcbc/bhsa/tf/2021
#    |     0.70s T prs_ps               from ~/github/etcbc/bhsa/tf/2021
#    |     0.68s T ps                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.40s T qere                 from ~/github/etcbc/bhsa/tf/2021
#    |     0.39s T qere_utf8            from ~/github/etcbc/bhsa/tf/2021
#    |     1.22s T rela                 from ~/github/etcbc/bhsa/tf/2021
#    |     0.72s T sp                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.70s T st                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.69s T suffix_gender        from ~/github/etcbc/bhsa/tf/2021
#    |     0.67s T suffix_number        from ~/github/etcbc/bhsa/tf/2021
#    |     0.68s T suffix_person        from ~/github/etcbc/bhsa/tf/2021
#    |     0.10s T tab                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.14s T txt                  from ~/github/etcbc/bhsa/tf/2021
#    |     1.21s T typ                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.68s T uvf                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.66s T vbe                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.73s T vbs                  from ~/github/etcbc/bhsa/tf/2021
#    |     0.73s T vs                   from ~/github/etcbc/bhsa/tf/2021
#    |     0.70s T vt                   from ~/github/etcbc/bhsa/tf/2021
#     41s All features loaded/computed - for details use TF.isLoaded()
# [('Computed',
#   'computed-data',
#   ('C Computed', 'Call AllComputeds', 'Cs ComputedString')),
#  ('Features', 'edge-features', ('E Edge', 'Eall AllEdges', 'Es EdgeString')),
#  ('Fabric', 'loading', ('TF',)),
#  ('Locality', 'locality', ('L Locality',)),
#  ('Nodes', 'navigating-nodes', ('N Nodes',)),
#  ('Features',
#   'node-features',
#   ('F Feature', 'Fall AllFeatures', 'Fs FeatureString')),
#  ('Search', 'search', ('S Search',)),
#  ('Text', 'text', ('T Text',))]

# %% [markdown]
# # Examples

# %%
utils.caption(4, "Basic test")
utils.caption(4, "First verse in all formats")
for fmt in T.formats:
    utils.caption(0, "{}".format(fmt), continuation=True)
    utils.caption(0, "\t{}".format(T.text(range(1, 12), fmt=fmt)), continuation=True)
# Out:
# ..............................................................................................
# .     21m 43s Basic test                                                                     .
# ..............................................................................................
# ..............................................................................................
# .     21m 43s First verse in all formats                                                     .
# ..............................................................................................
# lex-orig-full
# 	בְּ רֵאשִׁית בָּרָא אֱלֹה אֵת הַ שָּׁמַי וְ אֵת הָ אָרֶץ
# lex-orig-plain
# 	ב ראשׁית֜ ברא אלהים֜ את ה שׁמים֜ ו את ה ארץ֜
# lex-trans-full
# 	B.:- R;>CIJT B.@R@> >:ELOH >;T HA- C.@MAJ W:- >;T H@- >@REY
# lex-trans-plain
# 	B R>CJT/ BR>[ >LHJM/ >T H CMJM/ W >T H >RY/
# text-orig-full
# 	בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃
# text-orig-plain
# 	בראשׁית ברא אלהים את השׁמים ואת הארץ׃
# text-trans-full
# 	B.:-R;>CI73JT B.@R@74> >:ELOHI92JM >;71T HA-C.@MA73JIM W:->;71T H@->@75REY00
# text-trans-plain
# 	BR>CJT BR> >LHJM >T HCMJM W>T H>RY00

# %%
if SCRIPT:
    stop(good=True)

# %%
f = "subphrase_type"
print("`" + "` `".join(sorted(str(x[0]) for x in Fs(f).freqList())) + "`")
# Out:
#     15s Node feature "subphrase_type" not loaded
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ecb467d6013a> in <module>
#       1 f = 'subphrase_type'
# ----> 2 print('`' + '` `'.join(sorted(str(x[0]) for x in Fs(f).freqList())) + '`')
#
# AttributeError: 'NoneType' object has no attribute 'freqList'
