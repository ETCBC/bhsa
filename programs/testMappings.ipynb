# %%
from tf.app import use

# %%
AF = use("bhsa:clone", checkout="clone", version="c")
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-bhsa/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/bhsa/tf/c</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/phono/tf/c</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/parallels/tf/c</span>
# This is Text-Fabric 9.1.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 120 features found and 0 ignored
# ...

# %%
AT = use("bhsa:clone", checkout="clone", version="2021")
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-bhsa/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/bhsa/tf/2021</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/phono/tf/2021</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/parallels/tf/2021</span>
# This is Text-Fabric 9.1.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 122 features found and 0 ignored
# ...

# %%
nodeT = 1437865
print(AT.api.F.otype.v(nodeT))
# Out:
# 'lex'

# %%
for (nodeF, x) in AT.api.Es("omap@c-2021").t(nodeT):
    print(f"{AF.api.F.otype.v(nodeF):<15} {nodeF}")
# Out:
# lex             1437830
# lex             1437571

# %%
AT.api.F.lex.v(nodeT)
# Out:
# '>T=='

# %%
for (nodeF, penalty) in AT.api.Es("omap@c-2021").t(nodeT):
    print(f"{AF.api.F.lex.v(nodeF):<15} {nodeF} with penalty {penalty}")
# Out:
# >T==            1437830 with quality 2
# >T              1437571 with quality 11863

# %%
lexTeqeq = 1437830
lexT = 1437571
nodesTeqeq = AF.api.F.lex.s(">T==")
nodesT = AF.api.F.lex.s(">T")

# %%
len(nodesTeqeq)
# Out:
# 877

# %%
len(nodesT)
# Out:
# 10990
