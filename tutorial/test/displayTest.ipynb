# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("bhsa:clone", checkout="clone", hoist=globals())
# Out:
# Using TF-app in /Users/dirk/github/annotation/app-bhsa/code:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/etcbc/bhsa/tf/c:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/etcbc/phono/tf/c:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/etcbc/parallels/tf/c:
# 	repo clone offline under ~/github (local github)
#    |     0.00s No structure info in otext, the structure part of the T-API cannot be used
# ...

# %%
node = F.otype.s("sentence")[0]
words = L.d(node, otype="word")
phrases = L.d(node, otype="phrase")
highlights = {
    phrases[0]: "cyan",
    phrases[2]: "cyan",
    words[1]: "orange",
    words[6]: "orange",
}

# %%
# two phrase nodes and two word nodes to be highlighted
A.plain(node, baseType="word", highlights=highlights)

A.plain(node, baseType="phrase", highlights=highlights)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a><span class="plain outer  rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  hlbx"  style="border-color: cyan;" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  hl"  style="background-color: orange;" ><span class="h">רֵאשִׁ֖ית </span></span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  hlbx"  style="border-color: cyan;" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֱלֹהִ֑ים </span></span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  " ><span class
# ...

# %%
A.pretty(node, baseType="word", highlights=highlights)

A.pretty(node, baseType="phrase", highlights=highlights)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a><div class="outeritem"><div class="atoms  " ><div class="satom  " >
#         <div class="sentence " >
#             <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:1" sec="Genesis 1:1">sentence</a>   <span class="number">1</span>
#         </div>
#         <div class="atoms">
#                     <div class="catom  " >
#         <div class="clause " >
# ...

# %%
firstVerse = F.otype.s("verse")[0]
phrases = F.otype.s("phrase")[3:5]
words = (2, 4, 6, 9)

# %%
firstSentence = F.otype.s("sentence")[0]
A.plain(firstSentence, isLinked=False)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a><span class="plain outer  rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  " ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  " ><span class="h">הַ</span></span><span class="plain rtl  " ><span class="h">שָּׁמַ֖יִם </span></span><span class="plain rtl  " ><span class="h">וְ</span></span><span class="plain rtl 
# ...

# %% [markdown]
# First we highlight some words:

# %%
highlights = set(words)
A.plain(firstVerse, highlights=highlights)
# Out:
# <span class="plain outer  rtl  " ><span class="vrs ltr"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span><span class="plain rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  hl" ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  " ><span class="plain rtl  hl" ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  hl" ><span class="h">הַ</span></span><span class="plain rtl  " ><span class="h">שָּׁמַ֖יִם </span></span><span class="plain r
# ...

# %% [markdown]
# Now some phrases:

# %%
highlights = set(phrases)
A.plain(firstVerse, highlights=highlights)
A.pretty(firstVerse, highlights=highlights)
# Out:
# <span class="plain outer  rtl  " ><span class="vrs ltr"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span><span class="plain rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  " ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  " ><span class="h">הַ</span></span><span class="plain rtl  " ><span class="h">שָּׁמַ֖יִם </span></
# ...

# %% [markdown]
# As you see, when we highlight bigger things than words, we put a
# highlighted border around the words in those things.

# %% [markdown]
# We can do both:

# %%
highlights = set(phrases) | set(words)
A.plain(firstVerse, highlights=highlights)
A.pretty(firstVerse, highlights=highlights)
# Out:
# <span class="plain outer  rtl  " ><span class="vrs ltr"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span><span class="plain rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  hl" ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  " ><span class="plain rtl  hl" ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  hl" ><span class="h">הַ</span></span><span class="plain rtl  " ><span class="h">שָּׁמַ֖יִם </s
# ...

# %% [markdown]
# We can also highlight the verse itself.

# %%
highlights = {firstVerse}
A.plain(firstVerse, highlights=highlights)
# Out:
# <span class="plain outer  rtl  hlbx" ><span class="vrs ltr"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span><span class="plain rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בְּ</span></span><span class="plain rtl  " ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">בָּרָ֣א </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֵ֥ת </span></span><span class="plain rtl  " ><span class="h">הַ</span></span><span class="plain rtl  " ><span class="h">שָּׁמַ֖יִם </span></span><span class="plain rtl
# ...

# %% [markdown]
# As you see, only the verse label is highlighted, not the contents.
# The same policy is followed for chapters and books.

# %% [markdown]
# We can use different colours for highlighting.
# Lets use two colours for words and yet another color for phrases.

# %%
highlights = {i: "lightsalmon" for i in [1, 5, 9]}
highlights.update({i: "mediumaquamarine" for i in [3, 7]})
highlights.update({i: "blue" for i in phrases})
highlights.update({firstVerse: "#ff8822"})
A.plain(firstVerse, highlights=highlights, withNodes=True)
# Out:
# <span class="plain outer  rtl  hlbx"  style="border-color: #ff8822;" ><span class="vrs ltr"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span><span class="plain rtl "><span class="plain nd">1414354</span><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  hl"  style="background-color: lightsalmon;" ><span class="h">בְּ</span><span class="plain nd">1</span></span><span class="plain rtl  " ><span class="h">רֵאשִׁ֖ית </span></span></span><span class="plain rtl  " ><span class="plain rtl  hl"  style="background-color: mediumaquamarine;" ><span class="h">בָּרָ֣א </span><span class="plain nd">3</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">אֱלֹהִ֑ים </span></span></span><span class="plain
# ...

# %%
c2query = """
clause
  clause_atom
    word sp=verb
  < clause_atom
"""
results = A.search(c2query)
# Out:
#   0.88s 1075 results

# %%
A.table(results, end=3)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">clause</th><th>clause_atom</th><th>word</th><th>clause_atom</th>
# </tr>
#
# ...

# %%
result = results[9]
(clause, clause_atom1, word, clause_atom2) = result

# %%
A.plain(clause, withNodes=False)
A.plain(clause, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl "><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">שְׁמֹנֶ֥ה </span></span><span class="plain rtl  " ><span class="h">מֵאֹ֖ת </span></span><span class="plain rtl  " ><span class="h">שָׁנָ֑ה </span></span></span></span></span>
# ...

# %%
A.plain(clause_atom1, withNodes=False)
A.plain(clause_atom1, withNodes=True)
A.pretty(clause_atom1, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span>
# ...

# %%
highlights = {clause_atom1}
A.plain(clause_atom1, withNodes=False, highlights=highlights)
A.plain(clause_atom1, withNodes=True, highlights=highlights)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span>
# ...

# %%
highlights = {clause_atom1, clause_atom2}
A.plain(clause, highlights=highlights, withNodes=False)
A.plain(clause, highlights=highlights, withNodes=True)
A.pretty(clause, highlights=highlights, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl "><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">שְׁמֹנֶ֥ה </span></span><span class="plain rtl  " ><span class="h">מֵאֹ֖ת </span></span><span class="plain rtl  " ><span class="h">שָׁנָ֑ה </span></span></span></span></span>
# ...

# %%
highlights = {clause}
A.plain(clause, highlights=highlights, withNodes=False)
A.plain(clause, highlights=highlights, withNodes=True)
A.pretty(clause, highlights=highlights, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl "><span class="plain rtl  l hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span></span><span class="plain rtl  r hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">שְׁמֹנֶ֥ה </span></span><span class="plain rtl  " ><span class="h">מֵאֹ֖ת </span></span><span class="plain rtl  " ><span class="h">שָׁנָ֑ה </span></span>
# ...

# %%
highlights = {clause, clause_atom1, clause_atom2}
A.plain(clause, highlights=highlights, withNodes=False)
A.plain(clause, highlights=highlights, withNodes=True)
A.pretty(clause, highlights=highlights, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=5&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 5:4">Genesis 5:4</a><span class="plain outer  rtl "><span class="plain rtl  l hlbx" ><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יִּֽהְי֣וּ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">יְמֵי־</span></span><span class="plain rtl  " ><span class="h">אָדָ֗ם </span></span></span></span></span><span class="plain rtl  r hlbx" ><span class="plain rtl  hlbx" ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">שְׁמֹנֶ֥ה </span></span><span class="plain rtl  " ><span class="h">מֵאֹ֖ת </span></span><span class="plain rtl  " ><span class="h">שָׁנָ֑ה </span
# ...

# %%
ellipQuery = """
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
"""

# %%
results = A.search(ellipQuery)
len(results)
# Out:
#   2.19s 1472 results
# 1472

# %%
result = results[9]
(sentence, clause1, phrase1, word1, clause2, phrase2, clause3, phrase3, word3) = result
highlights = set(result)
A.plain(clause1, highlights=highlights, withNodes=True)
A.pretty(clause1, highlights=highlights, withNodes=True)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 18:8">Exodus 18:8</a><span class="plain outer  rtl "><span class="plain rtl  hlbx" ><span class="nd plain">435507</span><span class="plain rtl  " ><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">וַ</span></span></span><span class="plain rtl  hlbx" ><span class="nd plain">675472</span><span class="plain rtl  " ><span class="plain rtl  hl" ><span class="h">יְסַפֵּ֤ר </span><span class="plain nd">38605</span></span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">מֹשֶׁה֙ </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><span class="h">לְ</span></span><span class="plain rtl  " ><span class="h">חֹ֣תְנֹ֔ו </span></span></span><span class="plain rtl  " ><span class="plain rtl  " ><
# ...

# %%
A.table(results, start=10, end=20)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">sentence</th><th>clause</th><th>phrase</th><th>word</th><th>clause</th><th>phrase</th><th>clause</th><th>phrase</th><th>word</th>
# </tr>
#
# ...

# %%
A.show(results, start=10, end=14, withNodes=True)
# Out:
# <p><b>result</b> <i>10</i></p>
# <div class="outeritem"><div class="verse  " >
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 18:8">Exodus 18:8</a></div>
#         <span class="nd">1416361</span>
#     </div>
# <div class="satom  hl" >
#         <div class="sentence hl" >
#             <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 18:8" sec="Exodus 18:8">sentence</a> <span class="nd">1178439</span>  <span class="number">15|1542</span>
#         </div>
#         <div class="atoms">
#                     <div class="catom  hl" >
#         <div class="clause hl" >
# ...

# %%
A.show(results, start=10, end=14, withNodes=True, condenseType="sentence")
# Out:
# <p><b>result</b> <i>10</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 18:8">Exodus 18:8</a><div class="outeritem"><div class="atoms  " ><span class="nd">1178439</span><div class="satom  " >
#         <div class="sentence " >
#             <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 18:8" sec="Exodus 18:8">sentence</a> <span class="nd">1178439</span>  <span class="number">15|1542</span>
#         </div>
#         <div class="atoms">
#                     <div class="catom  hl" >
#         <div class="clause hl" >
# ...

# %% [markdown]
# And if we want to make life harder for ourselves, we can leave the passage indicators out as well.

# %%
A.show(
    results,
    start=10,
    end=14,
    withNodes=True,
    condenseType="sentence",
    withPassage=False,
)
# Out:
# <p><b>result</b> <i>10</i></p>
# <div class="atoms  " >
# <span class="nd">1178439</span>
#
#
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 18:8" sec="Exodus 18:8">sentence</a> <span class="nd">1178439</span>  <span class="number">15|1542</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=18&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 18:8" sec="Exodus 18:8">clause</a> <span class="nd">435507</span>  <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
# ...
