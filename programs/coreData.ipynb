# %% [markdown]
# <img align="right" src="tf-small.png"/>
#
# ![mql](emdros.png)
#
# # TF from MQL
#
# This notebook can read an
# [MQL](https://emdros.org/mql.html)
# dump of a version of the [BHSA](https://github.com/ETCBC/bhsa) Hebrew Text Database
# and transform it in a Text-Fabric
# [Text-Fabric](https://github.com/ETCBC/text-fabric)
# resource.
#
# ## Discussion
#
# The principled way of going about such a conversion is to import the MQL source into
# an [Emdros](https://emdros.org) database, and use it to retrieve objects and features from there.
#
# Because the syntax of an MQL file leaves some freedom, it is error prone to do a text-to-text conversion from
# MQL to something else.
#
# Yet this is what we do, the error-prone thing. We then avoid installing and configuring and managing Emdros, MySQL/sqLite3.
# Aside the upfront work to get this going, the going after that would also be much slower.
#
# So here you are, a smallish script to do an awful lot of work, mostly correct, if careful used.
#
# # Caveat
#
# This notebook makes use of a new feature of text-fabric, first present in 2.3.12.
# Make sure to upgrade first.
#
# ```sudo -H pip3 install --upgrade text-fabric
# ```

# %%
import os,sys,re,collections
from shutil import rmtree
from tf.fabric import Fabric
import utils

# %% [markdown]
# # Pipeline
# See [operation](https://github.com/ETCBC/pipeline/blob/master/README.md#operation)
# for how to run this script in the pipeline.

# %%
if 'SCRIPT' not in locals():
    SCRIPT = False
    FORCE = True
    CORE_NAME = 'bhsa'
    VERSION = 'c'

def stop(good=False):
    if SCRIPT: sys.exit(0 if good else 1)

# %% [markdown]
# # Setting up the context: source file and target directories
#
# The conversion is executed in an environment of directories, so that sources, temp files and
# results are in convenient places and do not have to be shifted around.

# %%
repoBase = os.path.expanduser('~/github/etcbc')
thisRepo = '{}/{}'.format(repoBase, CORE_NAME)

thisSource = '{}/source/{}'.format(thisRepo, VERSION)
mqlzFile = '{}/{}.mql.bz2'.format(thisSource, CORE_NAME)

thisTemp = '{}/_temp/{}'.format(thisRepo, VERSION)
thisTempSource = '{}/source'.format(thisTemp)
mqlFile = '{}/{}.mql'.format(thisTempSource, CORE_NAME)
thisTempTf = '{}/tf'.format(thisTemp)

thisTf = '{}/tf/{}'.format(thisRepo, VERSION)

# %% [markdown]
# # Test
#
# Check whether this conversion is needed in the first place.
# Only when run as a script.

# %%
if SCRIPT:
    testFile = '{}/.tf/otype.tfx'.format(thisTf)
    (good, work) = utils.mustRun(mqlzFile, '{}/.tf/otype.tfx'.format(thisTf), force=FORCE)
    if not good: stop(good=False)
    if not work: stop(good=True)

# %% [markdown]
# # TF Settings
#
# We add some custom information here.
#
# * the MQL object type that corresponds to the TF slot type, typically `word`;
# * a piece of metadata that will go into every feature; the time will be added automatically
# * suitable text formats for the `otext` feature of TF.
#
# The oText feature is very sensitive to what is available in the source MQL.
# It needs to be configured here.
# We save the configs we need per source and version.
# And we define a stripped down default version to start with.

# %%
slotType = 'word'

featureMetaData = dict(
    dataset='BHSA',
    datasetName='Biblia Hebraica Stuttgartensia Amstelodamensis',
    author='Eep Talstra Centre for Bible and Computer',
    encoders='Constantijn Sikkel (QDF), Ulrik Petersen (MQL) and Dirk Roorda (TF)',
    website='https://shebanq.ancient-data.org',
    email='shebanq@ancient-data.org',
)

oText = {
    '': {
        '': '''
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
@fmt:text-orig-full={g_word_utf8}{g_suffix_utf8}
''',
    },
    '4': '''
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_qere_utf8/g_word_utf8}{qtrailer_utf8/trailer_utf8}
@fmt:text-orig-full-ketiv={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word} 
@fmt:text-trans-full-ketiv={g_word} 
@fmt:text-trans-plain={g_cons} 
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
''',
    '4b': '''
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_qere_utf8/g_word_utf8}{qtrailer_utf8/trailer_utf8}
@fmt:text-orig-full-ketiv={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word} 
@fmt:text-trans-full-ketiv={g_word} 
@fmt:text-trans-plain={g_cons} 
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
''',
    'c': '''
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
''',
    '2016': '''
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
''',
    '2017': '''
@fmt:lex-orig-full={g_lex_utf8} 
@fmt:lex-orig-plain={lex_utf8} 
@fmt:lex-trans-full={g_lex} 
@fmt:lex-trans-plain={lex} 
@fmt:text-orig-full={g_word_utf8}{trailer_utf8}
@fmt:text-orig-plain={g_cons_utf8}{trailer_utf8}
@fmt:text-trans-full={g_word}{trailer}
@fmt:text-trans-plain={g_cons}{trailer}
@sectionFeatures=book,chapter,verse
@sectionTypes=book,chapter,verse
''',
}

# %% [markdown]
# The next function selects the proper otext material, falling back on a default if nothing
# appropriate has been specified in `oText`.

# %%
thisOtext = oText.get(VERSION, oText[''])

if thisOtext is oText['']:
    utils.caption(0, 'WARNING: no otext feature info provided, using a meager default value')
    otextInfo = {}
else:
    utils.caption(0, 'INFO: otext feature information found')
    otextInfo = dict(line[1:].split('=', 1) for line in thisOtext.strip('\n').split('\n'))
    for x in sorted(otextInfo.items()):
        utils.caption(0, '\t{:<20} = "{}"'.format(*x))
# Out:
# |       0.00s INFO: otext feature information found
# |       0.00s 	fmt:lex-orig-full    = "{g_lex_utf8} "
# |       0.00s 	fmt:lex-orig-plain   = "{lex_utf8} "
# |       0.00s 	fmt:lex-trans-full   = "{g_lex} "
# |       0.00s 	fmt:lex-trans-plain  = "{lex} "
# |       0.00s 	fmt:text-orig-full   = "{g_word_utf8}{trailer_utf8}"
# |       0.00s 	fmt:text-orig-plain  = "{g_cons_utf8}{trailer_utf8}"
# |       0.00s 	fmt:text-trans-full  = "{g_word}{trailer}"
# |       0.00s 	fmt:text-trans-plain = "{g_cons}{trailer}"
# |       0.00s 	sectionFeatures      = "book,chapter,verse"
# |       0.00s 	sectionTypes         = "book,chapter,verse"

# %% [markdown]
# # Overview
#
# The program has several stages:
#
# 1. **prepare** the source (utils.bunzip if needed)
# 1. **parse MQL** and collect information in datastructures
# 1. **transform to TF** write the datastructures as TF features
# 1. **differences** (informational)
# 1. **deliver** the tf data at its destination directory
# 1. **compile** all tf features to binary format

# %% [markdown]
# # Prepare
#
# Check the source, utils.bunzip it if needed, empty the result directory.

# %%
if not os.path.exists(thisTempSource):
    os.makedirs(thisTempSource)

utils.caption(0, 'bunzipping {} ...'.format(mqlzFile))
utils.bunzip(mqlzFile, mqlFile)
utils.caption(0, 'Done')

if os.path.exists(thisTempTf): rmtree(thisTempTf)
os.makedirs(thisTempTf)
# Out:
# |       0.02s bunzipping /Users/dirk/github/etcbc/bhsa/source/c/bhsa.mql.bz2 ...
# |       0.02s 	NOTE: Using existing unzipped file which is newer than bzipped one
# |       0.02s Done

# %% [markdown]
# Convert a monads specification (a comma separated sequence of numbers and number ranges)
# into a set of integers.

# %% [markdown]
# # MQL to Text-Fabric
# Transform the collected information in feature-like datastructures, and write it all
# out to `.tf` files.

# %%
TF = Fabric(locations=thisTempTf, silent=True)
TF.importMQL(mqlFile, slotType=slotType, otext=otextInfo, meta=featureMetaData)
#importMQL(mqlFile, thisTempTf, slotType=slotType, otext=otextInfo, meta=featureMetadata)
# Out:
#   0.00s Parsing mql source ...
#   0.00s 		enum boolean_t
#   0.00s 		enum phrase_determination_t
#   0.00s 		enum language_t
#   0.01s 		enum book_name_t
#   0.01s 		enum lexical_set_t
#   0.01s 		enum verbal_stem_t
#   0.01s 		enum verbal_tense_t
#   0.01s 		enum person_t
#   0.01s 		enum number_t
#   0.02s 		enum gender_t
#   0.02s 		enum state_t
#   0.02s 		enum part_of_speech_t
#   0.02s 		enum phrase_type_t
#   0.02s 		enum phrase_atom_relation_t
#   0.03s 		enum phrase_relation_t
#   0.03s 		enum phrase_atom_unit_distance_to_mother_t
#   0.03s 		enum subphrase_relation_t
#   0.03s 		enum subphrase_mother_object_type_t
#   0.03s 		enum phrase_function_t
#   0.03s 		enum clause_atom_type_t
#   0.04s 		enum clause_type_t
#   0.04s 		enum clause_kind_t
#   0.04s 		enum clause_constituent_relation_t
#   0.04s 		enum clause_constituent_mother_object_type_t
#   0.04s 		enum clause_constituent_unit_distance_to_mother_t
#   0.04s 		otype word
#   0.04s 			feature number (int) =def= 0 : node
#   0.05s 			feature g_voc_lex (str) =def=  : node
#   0.05s 			feature g_vbe_utf8 (str) =def=  : node
#   0.05s 			feature g_voc_lex_utf8 (str) =def=  : node
#   0.05s 			feature g_nme (str) =def=  : node
#   0.05s 			feature nme (str) =def=  : node
#   0.05s 			feature g_vbe (str) =def=  : node
#   0.05s 			feature g_word (str) =def=  : node
#   0.06s 			feature g_cons_utf8 (str) =def=  : node
#   0.06s 			feature g_cons (str) =def=  : node
#   0.06s 			feature g_word_utf8 (str) =def=  : node
#   0.06s 			feature trailer (str) =def=  : node
#   0.06s 			feature trailer_utf8 (str) =def=  : node
#   0.06s 			feature g_pfm (str) =def=  : node
#   0.06s 			feature g_pfm_utf8 (str) =def=  : node
#   0.06s 			feature g_vbs (str) =def=  : node
#   0.07s 			feature g_vbs_utf8 (str) =def=  : node
#   0.07s 			feature lex (str) =def=  : node
#   0.07s 			feature lex_utf8 (str) =def=  : node
#   0.07s 			feature g_lex (str) =def=  : node
#   0.07s 			feature g_lex_utf8 (str) =def=  : node
#   0.07s 			feature g_prs_utf8 (str) =def=  : node
#   0.07s 			feature g_prs (str) =def=  : node
#   0.07s 			feature qere_utf8 (str) =def=  : node
#   0.07s 			feature g_uvf_utf8 (str) =def=  : node
#   0.08s 			feature g_uvf (str) =def=  : node
#   0.08s 			feature qere (str) =def=  : node
#   0.08s 			feature g_nme_utf8 (str) =def=  : node
#   0.08s 			feature functional_parent (str) =def= 0 : edge
#   0.08s 			feature distributional_parent (str) =def= 0 : edge
#   0.08s 			feature pfm (str) =def=  : node
#   0.08s 			feature prs (str) =def=  : node
#   0.09s 			feature uvf (str) =def=  : node
#   0.09s 			feature vbe (str) =def=  : node
#   0.09s 			feature vbs (str) =def=  : node
#   0.09s 			feature language (str) =def= Hebrew : node
#   0.09s 			feature ls (str) =def= none : node
#   0.09s 			feature vs (str) =def= NA : node
#   0.10s 			feature vt (str) =def= NA : node
#   0.10s 			feature prs_ps (str) =def= NA : node
#   0.10s 			feature ps (str) =def= NA : node
#   0.10s 			feature nu (str) =def= NA : node
#   0.10s 			feature prs_nu (str) =def= NA : node
#   0.10s 			feature prs_gn (str) =def= NA : node
#   0.10s 			feature gn (str) =def= NA : node
#   0.10s 			feature st (str) =def= NA : node
#   0.10s 			feature sp (str) =def= art : node
#   0.10s 			feature pdp (str) =def= art : node
#   0.11s 		otype clause_atom
#   0.11s 			feature tab (int) =def= 0 : node
#   0.11s 			feature code (int) =def= 0 : node
#   0.11s 			feature dist (int) =def= 0 : node
#   0.11s 			feature number (int) =def= 0 : node
#   0.11s 			feature distributional_parent (str) =def= 0 : edge
#   0.11s 			feature mother (str) =def= 0 : edge
#   0.12s 			feature functional_parent (str) =def= 0 : edge
#   0.12s 			feature is_root (str) =def= false : node
#   0.12s 			feature typ (str) =def= Unkn : node
#   0.12s 		otype sentence
#   0.12s 			feature number (int) =def= 0 : node
#   0.13s 		otype sentence_atom
#   0.13s 			feature number (int) =def= 0 : node
#   0.13s 			feature functional_parent (str) =def= 0 : edge
#   0.13s 		otype subphrase
#   0.13s 			feature mother (str) =def= 0 : edge
#   0.13s 			feature rela (str) =def= NA : node
#   0.13s 			feature mother_object_type (str) =def= NA : node
#   0.13s 		otype phrase
#   0.13s 			feature dist (int) =def= 0 : node
#   0.13s 			feature number (int) =def= 0 : node
#   0.14s 			feature functional_parent (str) =def= 0 : edge
#   0.14s 			feature mother (str) =def= 0 : edge
#   0.14s 			feature det (str) =def= NA : node
#   0.14s 			feature typ (str) =def= VP : node
#   0.14s 			feature rela (str) =def= NA : node
#   0.14s 			feature dist_unit (str) =def= clause_atoms : node
#   0.14s 			feature function (str) =def= Unkn : node
#   0.14s 		otype chapter
#   0.14s 			feature chapter (int) =def= 0 : node
#   0.15s 			feature book (str) =def= Genesis : node
#   0.15s 		otype book
#   0.15s 			feature book (str) =def= Genesis : node
#   0.15s 		otype clause
#   0.15s 			feature dist (int) =def= 0 : node
#   0.15s 			feature number (int) =def= 0 : node
#   0.16s 			feature domain (str) =def=  : node
#   0.19s 			feature mother (str) =def= 0 : edge
#   0.19s 			feature functional_parent (str) =def= 0 : edge
#   0.20s 			feature txt (str) =def=  : node
#   0.20s 			feature typ (str) =def= Unkn : node
#   0.20s 			feature kind (str) =def= unknown : node
#   0.21s 			feature rela (str) =def= NA : node
#   0.22s 			feature mother_object_type (str) =def= clause : node
#   0.24s 			feature dist_unit (str) =def= clause_atoms : node
#   0.26s 		otype half_verse
#   0.26s 			feature label (str) =def=  : node
#   0.26s 		otype verse
#   0.27s 			feature verse (int) =def= 0 : node
#   0.27s 			feature chapter (int) =def= 0 : node
#   0.27s 			feature label (str) =def=  : node
#   0.27s 			feature book (str) =def= Genesis : node
#   0.27s 		otype phrase_atom
#   0.28s 			feature number (int) =def= 0 : node
#   0.28s 			feature dist (int) =def= 0 : node
#   0.29s 			feature distributional_parent (str) =def= 0 : edge
#   0.29s 			feature mother (str) =def= 0 : edge
#   0.29s 			feature functional_parent (str) =def= 0 : edge
#   0.30s 			feature det (str) =def= NA : node
#   0.30s 			feature typ (str) =def= VP : node
#   0.30s 			feature rela (str) =def= NA : node
#   0.30s 			feature dist_unit (str) =def= clause_atoms : node
#   0.31s 		objects in word
#   7.02s 	line   1000000
#     13s 	line   2000000
#     17s 		objects in word
#     19s 	line   3000000
#     25s 	line   4000000
#     32s 	line   5000000
#     33s 		objects in word
#     39s 	line   6000000
#     46s 	line   7000000
#     51s 		objects in word
#     52s 	line   8000000
#     58s 	line   9000000
#  1m 05s 	line  10000000
#  1m 07s 		objects in word
#  1m 11s 	line  11000000
#  1m 17s 	line  12000000
#  1m 24s 	line  13000000
#  1m 24s 		objects in word
#  1m 30s 	line  14000000
#  1m 36s 	line  15000000
#  1m 40s 		objects in word
#  1m 42s 	line  16000000
#  1m 48s 	line  17000000
#  1m 54s 	line  18000000
#  1m 56s 		objects in word
#  2m 01s 	line  19000000
#  2m 07s 	line  20000000
#  2m 11s 		objects in word
#  2m 13s 	line  21000000
#  2m 19s 	line  22000000
#  2m 20s 		objects in clause_atom
#  2m 22s 		objects in clause_atom
#  2m 23s 	line  23000000
#  2m 25s 		objects in sentence
#  2m 26s 		objects in sentence
#  2m 26s 		objects in sentence_atom
#  2m 27s 		objects in sentence_atom
#  2m 27s 	line  24000000
#  2m 27s 		objects in subphrase
#  2m 29s 		objects in subphrase
#  2m 30s 		objects in subphrase
#  2m 30s 		objects in phrase
#  2m 31s 	line  25000000
#  2m 33s 		objects in phrase
#  2m 35s 	line  26000000
#  2m 35s 		objects in phrase
#  2m 38s 		objects in phrase
#  2m 39s 	line  27000000
#  2m 40s 		objects in phrase
#  2m 42s 	line  28000000
#  2m 42s 		objects in phrase
#  2m 42s 		objects in chapter
#  2m 43s 		objects in book
#  2m 43s 		objects in clause
#  2m 46s 		objects in clause
#  2m 47s 	line  29000000
#  2m 49s 		objects in half_verse
#  2m 50s 		objects in verse
#  2m 51s 		objects in phrase_atom
#  2m 51s 	line  30000000
#  2m 53s 		objects in phrase_atom
#  2m 55s 	line  31000000
#  2m 55s 		objects in phrase_atom
#  2m 59s 		objects in phrase_atom
#  2m 59s 	line  32000000
#  3m 01s 		objects in phrase_atom
#  3m 03s 	line  33000000
#  3m 03s 		objects in phrase_atom
#  3m 04s 33367199 lines parsed
#  3m 04s 426581 objects of type word
#  3m 04s 90562 objects of type clause_atom
#  3m 04s 63570 objects of type sentence
#  3m 04s 64339 objects of type sentence_atom
#  3m 04s 113792 objects of type subphrase
#  3m 04s 253174 objects of type phrase
#  3m 04s 929 objects of type chapter
#  3m 04s 39 objects of type book
#  3m 04s 88000 objects of type clause
#  3m 04s 45180 objects of type half_verse
#  3m 04s 23213 objects of type verse
#  3m 04s 267515 objects of type phrase_atom
#  3m 04s Making TF data ...
#  3m 04s Monad - idd mapping ...
#  3m 05s maxSlot=426581
#  3m 05s Node mapping and otype ...
#  3m 05s oslots ...
#  3m 06s metadata ...
#  3m 06s features ...
#  3m 06s 	features from words
#  3m 10s 	   100000 words
#  3m 14s 	   200000 words
#  3m 18s 	   300000 words
#  3m 22s 	   400000 words
#  3m 23s 	   426581 words
#  3m 23s 	features from books
#  3m 23s 	       39 books
#  3m 23s 	features from chapters
#  3m 23s 	      929 chapters
#  3m 23s 	features from clauses
#  3m 24s 	    88000 clauses
#  3m 24s 	features from clause_atoms
#  3m 26s 	    90562 clause_atoms
#  3m 26s 	features from half_verses
#  3m 26s 	    45180 half_verses
#  3m 26s 	features from phrases
#  3m 27s 	   100000 phrases
#  3m 28s 	   200000 phrases
#  3m 28s 	   253174 phrases
#  3m 28s 	features from phrase_atoms
#  3m 29s 	   100000 phrase_atoms
#  3m 30s 	   200000 phrase_atoms
#  3m 31s 	   267515 phrase_atoms
#  3m 31s 	features from sentences
#  3m 31s 	    63570 sentences
#  3m 31s 	features from sentence_atoms
#  3m 31s 	    64339 sentence_atoms
#  3m 31s 	features from subphrases
#  3m 31s 	   100000 subphrases
#  3m 31s 	   113792 subphrases
#  3m 31s 	features from verses
#  3m 31s 	    23213 verses
#    |     0.04s T book                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.05s T chapter              to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.16s T code                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.93s T det                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.24s T dist                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.13s T dist_unit            to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.16s T domain               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.47s T function             to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.79s T g_cons               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.90s T g_cons_utf8          to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.98s T g_lex                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.07s T g_lex_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.78s T g_nme                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.78s T g_nme_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.74s T g_pfm                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.74s T g_pfm_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.73s T g_prs                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.70s T g_prs_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.69s T g_uvf                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.70s T g_uvf_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.72s T g_vbe                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.68s T g_vbe_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.72s T g_vbs                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.69s T g_vbs_utf8           to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.84s T g_voc_lex            to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.79s T g_voc_lex_utf8       to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.92s T g_word               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.83s T g_word_utf8          to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.80s T gn                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.22s T is_root              to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.16s T kind                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.12s T label                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.95s T language             to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.10s T lex                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.93s T lex_utf8             to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.89s T ls                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.47s T mother_object_type   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.03s T nme                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.85s T nu                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     2.18s T number               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.65s T otype                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.81s T pdp                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.82s T pfm                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.76s T prs                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.79s T prs_gn               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.86s T prs_nu               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.79s T prs_ps               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.77s T ps                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.74s T qere                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.71s T qere_utf8            to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.38s T rela                 to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.79s T sp                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.81s T st                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.17s T tab                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.78s T trailer              to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.73s T trailer_utf8         to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.16s T txt                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     1.26s T typ                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.82s T uvf                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.77s T vbe                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.84s T vbs                  to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.04s T verse                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.77s T vs                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.81s T vt                   to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     2.63s T distributional_parent to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     3.70s T functional_parent    to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.58s T mother               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     4.27s T oslots               to /Users/dirk/github/etcbc/bhsa/_temp/c/tf
#    |     0.00s M otext                to /Users/dirk/github/etcbc/bhsa/_temp/c/tf

# %% [markdown]
# # Diffs
#
# Check differences with previous versions.
#
# The new dataset has been created in a temporary directory,
# and has not yet been copied to its destination.
#
# Here is your opportunity to compare the newly created features with the older features.
# You expect some differences in some features.
#
# We check the differences between the previous version of the features and what has been generated.
# We list features that will be added and deleted and changed.
# For each changed feature we show the first line where the new feature differs from the old one.
# We ignore changes in the metadata, because the timestamp in the metadata will always change.

# %%
utils.checkDiffs(thisTempTf, thisTf)
# Out:
# ..............................................................................................
# .      5m 00s Check differences with previous version                                        .
# ..............................................................................................
# |      5m 00s 	no features to add
# |      5m 00s 	26 features to delete
# |      5m 00s 		book@am
# |      5m 00s 		book@ar
# |      5m 00s 		book@bn
# |      5m 00s 		book@da
# |      5m 00s 		book@de
# |      5m 00s 		book@el
# |      5m 00s 		book@en
# |      5m 00s 		book@es
# |      5m 00s 		book@fa
# |      5m 00s 		book@fr
# |      5m 00s 		book@he
# |      5m 00s 		book@hi
# |      5m 00s 		book@id
# |      5m 00s 		book@ja
# |      5m 00s 		book@ko
# |      5m 00s 		book@la
# |      5m 00s 		book@nl
# |      5m 00s 		book@pa
# |      5m 00s 		book@pt
# |      5m 00s 		book@ru
# |      5m 00s 		book@sw
# |      5m 00s 		book@syc
# |      5m 00s 		book@tr
# |      5m 00s 		book@ur
# |      5m 00s 		book@yo
# |      5m 00s 		book@zh
# |      5m 00s 	69 features in common
# |      5m 00s book                      ... no changes
# |      5m 00s chapter                   ... no changes
# |      5m 00s code                      ... no changes
# |      5m 00s det                       ... no changes
# |      5m 01s dist                      ... no changes
# |      5m 01s dist_unit                 ... no changes
# |      5m 02s distributional_parent     ... no changes
# |      5m 03s domain                    ... no changes
# |      5m 03s function                  ... no changes
# |      5m 03s functional_parent         ... no changes
# |      5m 04s g_cons                    ... no changes
# |      5m 05s g_cons_utf8               ... no changes
# |      5m 05s g_lex                     ... no changes
# |      5m 06s g_lex_utf8                ... no changes
# |      5m 06s g_nme                     ... no changes
# |      5m 06s g_nme_utf8                ... no changes
# |      5m 07s g_pfm                     ... no changes
# |      5m 07s g_pfm_utf8                ... no changes
# |      5m 07s g_prs                     ... no changes
# |      5m 08s g_prs_utf8                ... no changes
# |      5m 08s g_uvf                     ... no changes
# |      5m 08s g_uvf_utf8                ... no changes
# |      5m 09s g_vbe                     ... no changes
# |      5m 09s g_vbe_utf8                ... no changes
# |      5m 09s g_vbs                     ... no changes
# |      5m 10s g_vbs_utf8                ... no changes
# |      5m 10s g_voc_lex                 ... no changes
# |      5m 11s g_voc_lex_utf8            ... no changes
# |      5m 11s g_word                    ... no changes
# |      5m 12s g_word_utf8               ... no changes
# |      5m 12s gn                        ... no changes
# |      5m 12s is_root                   ... no changes
# |      5m 13s kind                      ... no changes
# |      5m 13s label                     ... no changes
# |      5m 13s language                  ... no changes
# |      5m 13s lex                       ... no changes
# |      5m 13s lex_utf8                  ... no changes
# |      5m 14s ls                        ... no changes
# |      5m 14s mother                    ... no changes
# |      5m 15s mother_object_type        ... no changes
# |      5m 15s nme                       ... no changes
# |      5m 15s nu                        ... no changes
# |      5m 16s number                    ... no changes
# |      5m 17s oslots                    ... no changes
# |      5m 18s otext                     ... differences
# |      5m 18s 	line     19 OLD -->@dateWritten=2017-10-02T09:56:42Z<--
# |      5m 18s 	line     19 NEW -->@dateWritten=2017-10-02T11:57:58Z<--
#
# |      5m 18s otype                     ... no changes
# |      5m 18s pdp                       ... no changes
# |      5m 18s pfm                       ... no changes
# |      5m 19s prs                       ... no changes
# |      5m 19s prs_gn                    ... no changes
# |      5m 20s prs_nu                    ... no changes
# |      5m 20s prs_ps                    ... no changes
# |      5m 21s ps                        ... no changes
# |      5m 21s qere                      ... no changes
# |      5m 22s qere_utf8                 ... no changes
# |      5m 22s rela                      ... no changes
# |      5m 23s sp                        ... no changes
# |      5m 24s st                        ... no changes
# |      5m 24s tab                       ... no changes
# |      5m 24s trailer                   ... no changes
# |      5m 25s trailer_utf8              ... no changes
# |      5m 25s txt                       ... no changes
# |      5m 25s typ                       ... no changes
# |      5m 26s uvf                       ... no changes
# |      5m 27s vbe                       ... no changes
# |      5m 28s vbs                       ... no changes
# |      5m 28s verse                     ... no changes
# |      5m 28s vs                        ... no changes
# |      5m 29s vt                        ... no changes
# |      5m 29s Done

# %% [markdown]
# # Deliver
#
# Copy the new TF dataset from the temporary location where it has been created to its final destination.

# %%
utils.deliverDataset(thisTempTf, thisTf)
# Out:
# ..............................................................................................
# .      8m 01s Deliver data set to /Users/dirk/github/etcbc/bhsa/tf/c                         .
# ..............................................................................................

# %% [markdown]
# # Compile TF
#
# Just to see whether everything loads and the precomputing of extra information works out.
# Moreover, if you want to work with these features, then the precomputing has already been done, and everything is quicker in subsequent runs.
#
# We issue load statement to trigger the precomputing of extra data.
# Note that all features specified text formats in the `otext` config feature,
# will be loaded, as well as the features for sections.
#
# At that point we have access to the full list of features.
# We grab them and are going to load them all!

# %%
utils.caption(4, 'Load and compile standard TF features')
TF = Fabric(locations=thisTf, modules=[''])
api = TF.load('')

utils.caption(4, 'Load and compile all other TF features')
allFeatures = TF.explore(silent=False, show=True)
loadableFeatures = allFeatures['nodes'] + allFeatures['edges']
api = TF.load(loadableFeatures)
T = api.T

# %% [markdown]
# # Examples

# %%
utils.caption(4, 'Basic test')
utils.caption(4, 'First verse in all formats')
for fmt in T.formats:
    utils.caption(0, '{}'.format(fmt), continuation=True)
    utils.caption(0, '\t{}'.format(T.text(range(1,12), fmt=fmt)), continuation=True)
# Out:
# ..............................................................................................
# .      8m 08s Load and compile standard TF features                                          .
# ..............................................................................................
# This is Text-Fabric 2.3.15
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
#
# 69 features found and 0 ignored
#   0.00s loading features ...
#    |     0.83s T otype                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     9.80s T oslots               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.09s T book                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.05s T chapter              from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.04s T verse                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.41s T g_cons               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.57s T g_cons_utf8          from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.57s T g_lex                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.73s T g_lex_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.54s T g_word               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.66s T g_word_utf8          from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.44s T lex                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.59s T lex_utf8             from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.10s T trailer              from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.16s T trailer_utf8         from /Users/dirk/github/etcbc/bhsa/tf/c
#    |      |     1.22s C __levels__           from otype, oslots
#    |      |       17s C __order__            from otype, oslots, __levels__
#    |      |     0.90s C __rank__             from otype, __order__
#    |      |       18s C __levUp__            from otype, oslots, __rank__
#    |      |       10s C __levDown__          from otype, __levUp__, __rank__
#    |      |     3.61s C __boundary__         from otype, oslots, __rank__
#    |     0.00s M otext                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |      |     0.13s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.00s Feature overview: 64 for nodes; 4 for edges; 1 configs; 7 computed
#  1m 17s All features loaded/computed - for details use loadLog()
# ..............................................................................................
# .      9m 25s Load and compile all other TF features                                         .
# ..............................................................................................
#    |     0.00s Feature overview: 64 for nodes; 4 for edges; 1 configs; 7 computed
#   0.00s loading features ...
#    |     0.18s T code                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.79s T det                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.25s T dist                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     2.04s T dist_unit            from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     3.88s T distributional_parent from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.27s T domain               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.85s T function             from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     5.78s T functional_parent    from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.96s T g_nme                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.04s T g_nme_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.73s T g_pfm                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.71s T g_pfm_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.73s T g_prs                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.74s T g_prs_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.65s T g_uvf                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.65s T g_uvf_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.79s T g_vbe                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.69s T g_vbe_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.71s T g_vbs                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.65s T g_vbs_utf8           from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.52s T g_voc_lex            from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.63s T g_voc_lex_utf8       from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.40s T gn                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.30s T is_root              from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.30s T kind                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.22s T label                from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.46s T language             from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.43s T ls                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.24s T mother               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.67s T mother_object_type   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.21s T nme                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.43s T nu                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     2.36s T number               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.43s T pdp                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.40s T pfm                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.56s T prs                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.64s T prs_gn               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.65s T prs_nu               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.46s T prs_ps               from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.43s T ps                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.64s T qere                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.63s T qere_utf8            from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     2.44s T rela                 from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.42s T sp                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.36s T st                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.17s T tab                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.28s T txt                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     2.42s T typ                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.48s T uvf                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.34s T vbe                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.44s T vbs                  from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.43s T vs                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     1.46s T vt                   from /Users/dirk/github/etcbc/bhsa/tf/c
#    |     0.00s Feature overview: 64 for nodes; 4 for edges; 1 configs; 7 computed
#  1m 09s All features loaded/computed - for details use loadLog()
# ..............................................................................................
# .     10m 34s Basic test                                                                     .
# ..............................................................................................
# ..............................................................................................
# .     10m 34s First verse in all formats                                                     .
# ..............................................................................................
# lex-trans-plain
# 	B R>CJT/ BR>[ >LHJM/ >T H CMJM/ W >T H >RY/
# text-trans-plain
# 	BR>CJT BR> >LHJM >T HCMJM W>T H>RY00
# lex-orig-plain
# 	ב ראשׁית֜ ברא אלהים֜ את ה שׁמים֜ ו את ה ארץ֜
# text-orig-full
# 	בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃
# lex-trans-full
# 	B.:- R;>CIJT B.@R@> >:ELOH >;T HA- C.@MAJ W:- >;T H@- >@REY
# text-orig-plain
# 	בראשׁית ברא אלהים את השׁמים ואת הארץ׃
# text-trans-full
# 	B.:-R;>CI73JT B.@R@74> >:ELOHI92JM >;71T HA-C.@MA73JIM W:->;71T H@->@75REY00
# lex-orig-full
# 	בְּ רֵאשִׁית בָּרָא אֱלֹה אֵת הַ שָּׁמַי וְ אֵת הָ אָרֶץ
