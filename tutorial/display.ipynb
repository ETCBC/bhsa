# %% [markdown]
# # Rich display
#
# We have a new module, `bhsa.py`, that can display every node in a shebanq-like way.
# It can also display query results obtained by Text-Fabric search.

# %%
import sys, os
from IPython.display import display, HTML

# %% [markdown]
# ## New incantation
# Here comes the new incantation.
# The thrid part of `LOC` should be the name of the notebook you are writing.
# If you have your notebook in a github repo, you will get the link to its online version,
# on GitHub and on NBviewer.
#
# Note that handy documentation links are shown after loading.

# %%
LOC = ('~/github', 'etcbc/bhsa', 'display')
sys.path.append(os.path.expanduser(f'{LOC[0]}/{LOC[1]}/programs'))
from bhsa import Bhsa
B = Bhsa(*LOC)
B.api.makeAvailableIn(globals())
# Out:
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="{provenance of this corpus}">BHSA</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/0_home.html" title="{CORPUS} feature documentation">Feature docs</a> <a target="_blank" href="https://etcbc.github.io/bhsa/api.html" title="BHSA API documentation">BHSA API</a> <a target="_blank" href="https://github.com/Dans-labs/text-fabric/wiki/api" title="text-fabric-api">Text-Fabric API</a>
# This notebook online:
# <a target="_blank" href="http://nbviewer.jupyter.org/github/etcbc/bhsa/blob/master/tutorial/display.ipynb">NBViewer</a>
# <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/tutorial/display.ipynb">GitHub</a>
# <style>
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     direction: ltr;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.L,.catom.L,.patom.L {
#     border-left-style: none
# }
# .satom.R,.catom.R,.patom.R {
#     border-right-style: none
# }
# .h {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl;
# }
# .sp {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .gl {
#     font-family: sans-serif;
#     font-size: small;
#     color: #aaaaaa;
# }
# .vs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# </style>

# %% [markdown]
# A number of features has already been loaded.
# If you need more features, do it like this:

# %%
B.load('''
    vs vt
''')

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
B.pretty(651572)
# Out:
# <div class="atoms  ">
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651572</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עַ֣ל </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֑יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Verses
# Now a couple of verses:

# %%
verse1 = T.nodeFromSection(('Genesis', 1, 7))
verse2 = T.nodeFromSection(('Genesis', 1, 17))

# %%
B.pretty(verse1 )
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a></div><div class="nd">1414196</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172226</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427571</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651562</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651563</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַּ֣עַשׂ </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651564</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִים֮ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651565</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִיעַ֒ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172227</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause">clause <span class="nd">427572</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651566</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651567</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַּבְדֵּ֗ל </div>
#     <div class="sp">verb</div>
#     <div class="gl">separate</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֵּ֤ין </div>
#     <div class="sp">subs</div>
#     <div class="gl">interval</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַּ֨יִם֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">water</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427573</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651569</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">651570</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">תַּ֣חַת </div>
#     <div class="sp">subs</div>
#     <div class="gl">under part</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">651570</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֔יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r ">
#
#     <div class="clause">clause <span class="nd">427572</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֵ֣ין </div>
#     <div class="sp">subs</div>
#     <div class="gl">interval</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַּ֔יִם </div>
#     <div class="sp">subs</div>
#     <div class="gl">water</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427574</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651571</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁ֖ר </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651572</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עַ֣ל </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֑יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172228</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427575</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651573</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַֽ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651574</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְהִי־</div>
#     <div class="sp">verb</div>
#     <div class="gl">be</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651575</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֵֽן׃ </div>
#     <div class="sp">advb</div>
#     <div class="gl">thus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# The next verse without all those node numbers.

# %%
B.pretty(verse2, withNodes=False)
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#     </div>
#
# <div class="satom  L ">
#
#     <div class="sentence">sentence
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּתֵּ֥ן </div>
#     <div class="sp">verb</div>
#     <div class="gl">give</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹתָ֛ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רְקִ֣יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָּׁמָ֑יִם </div>
#     <div class="sp">subs</div>
#     <div class="gl">heavens</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָאִ֖יר </div>
#     <div class="sp">verb</div>
#     <div class="gl">be light</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אָֽרֶץ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">earth</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Query results
# We run a TF query and show some of its results with a lot of pomp and circumstance.
# The query is written by Stephen Ku, and he is the one who prompted me to write
# rich display function for query results.

# %%
ellipQuery = '''
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
'''

# %% [markdown]
# Instead of running `T.search()`, we do `B.search()`.

# %%
results = B.search(ellipQuery)
len(results)
# Out:
# 1410

# %% [markdown]
# Here it comes: the `B.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
B.show(results, 10, 20, withNodes=True)
# Out:
# ## Result 10
# (**sentence** `1229325`, **clause** `505922`, **phrase** `875983`, **word** `369666`, **clause** `505925`, **phrase** `875994`, **clause** `505928`, **phrase** `876005`, **word** `369720`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=20&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:20</a></div><div class="nd">1434580</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1229324</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505916</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875966</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875967</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּכְתֹּ֣ב </div>
#     <div class="sp">verb</div>
#     <div class="gl">write</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875968</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מָרְדֳּכַ֔י </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Mordecai</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875969</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְּבָרִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">word</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֑לֶּה </div>
#     <div class="sp">prde</div>
#     <div class="gl">these</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505917</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875970</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875971</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּשְׁלַ֨ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875972</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">סְפָרִ֜ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">letter</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875973</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִ֗ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505918</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875974</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינֹות֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">district</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מֶּ֣לֶךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲחַשְׁוֵרֹ֔ושׁ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Ahasuerus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505919</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875976</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875977</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">קְּרֹובִ֖ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">near</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505920</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875978</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875979</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875980</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">רְחֹוקִֽים׃ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">remote</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=21&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:21</a></div><div class="nd">1434581</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505921</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875981</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קַיֵּם֮ </div>
#     <div class="sp">verb</div>
#     <div class="gl">arise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875982</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עֲלֵיהֶם֒ </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505922</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">875983</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word   hl">
#
#     <div class="h">הְיֹ֣ות </div>
#     <div class="sp">verb</div>
#     <div class="gl">be</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875984</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עֹשִׂ֗ים </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֵ֠ת </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹ֣ום </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אַרְבָּעָ֤ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">four</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עָשָׂר֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">-teen</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֹ֣דֶשׁ </div>
#     <div class="sp">subs</div>
#     <div class="gl">month</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֲדָ֔ר </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Adar</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֵ֛ת </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹום־</div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֲמִשָּׁ֥ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">five</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עָשָׂ֖ר </div>
#     <div class="sp">subs</div>
#     <div class="gl">-teen</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֹּ֑ו </div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875986</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָׁנָ֖ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">year</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָׁנָֽה׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">year</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=22&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:22</a></div><div class="nd">1434582</div>
#     </div>
#
# <div class="satom  R  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כַּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">as</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּמִ֗ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505924</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875988</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר־</div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875989</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">נָ֨חוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">settle</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875990</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875991</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִים֙ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875992</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֹ֣ויְבֵיהֶ֔ם </div>
#     <div class="sp">verb</div>
#     <div class="gl">be hostile</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֹ֗דֶשׁ </div>
#     <div class="sp">subs</div>
#     <div class="gl">month</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505925</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875993</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֩ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">875994</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">נֶהְפַּ֨ךְ </div>
#     <div class="sp">verb</div>
#     <div class="gl">turn</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875995</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875996</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּגֹון֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">grief</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875997</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׂמְחָ֔ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">joy</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505926</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875998</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875999</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֖בֶל </div>
#     <div class="sp">subs</div>
#     <div class="gl">mourning rites</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876000</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹ֣ום </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">טֹ֑וב </div>
#     <div class="sp">adjv</div>
#     <div class="gl">good</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505927</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876001</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לַ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עֲשֹׂ֣ות </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876002</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹותָ֗ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876003</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְמֵי֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מִשְׁתֶּ֣ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">drinking</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
# ## Result 11
# (**sentence** `1229325`, **clause** `505922`, **phrase** `875983`, **word** `369666`, **clause** `505925`, **phrase** `875994`, **clause** `505928`, **phrase** `876005`, **word** `369721`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=20&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:20</a></div><div class="nd">1434580</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1229324</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505916</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875966</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875967</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּכְתֹּ֣ב </div>
#     <div class="sp">verb</div>
#     <div class="gl">write</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875968</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מָרְדֳּכַ֔י </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Mordecai</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875969</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְּבָרִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">word</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֑לֶּה </div>
#     <div class="sp">prde</div>
#     <div class="gl">these</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505917</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875970</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875971</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּשְׁלַ֨ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875972</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">סְפָרִ֜ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">letter</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875973</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִ֗ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505918</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875974</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינֹות֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">district</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מֶּ֣לֶךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲחַשְׁוֵרֹ֔ושׁ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Ahasuerus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505919</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875976</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875977</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">קְּרֹובִ֖ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">near</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505920</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875978</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875979</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875980</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">רְחֹוקִֽים׃ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">remote</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=21&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:21</a></div><div class="nd">1434581</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505921</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875981</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קַיֵּם֮ </div>
#     <div class="sp">verb</div>
#     <div class="gl">arise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875982</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עֲלֵיהֶם֒ </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505922</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">875983</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word   hl">
#
#     <div class="h">הְיֹ֣ות </div>
#     <div class="sp">verb</div>
#     <div class="gl">be</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875984</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עֹשִׂ֗ים </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֵ֠ת </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹ֣ום </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אַרְבָּעָ֤ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">four</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עָשָׂר֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">-teen</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֹ֣דֶשׁ </div>
#     <div class="sp">subs</div>
#     <div class="gl">month</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֲדָ֔ר </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Adar</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֵ֛ת </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹום־</div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֲמִשָּׁ֥ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">five</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עָשָׂ֖ר </div>
#     <div class="sp">subs</div>
#     <div class="gl">-teen</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875985</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֹּ֑ו </div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875986</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָׁנָ֖ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">year</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָׁנָֽה׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">year</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=22&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:22</a></div><div class="nd">1434582</div>
#     </div>
#
# <div class="satom  R  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כַּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">as</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּמִ֗ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505924</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875988</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר־</div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875989</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">נָ֨חוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">settle</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875990</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875991</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִים֙ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875992</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֹ֣ויְבֵיהֶ֔ם </div>
#     <div class="sp">verb</div>
#     <div class="gl">be hostile</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֹ֗דֶשׁ </div>
#     <div class="sp">subs</div>
#     <div class="gl">month</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505925</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875993</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֩ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">875994</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">נֶהְפַּ֨ךְ </div>
#     <div class="sp">verb</div>
#     <div class="gl">turn</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875995</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875996</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּגֹון֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">grief</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875997</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׂמְחָ֔ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">joy</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505926</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875998</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875999</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֖בֶל </div>
#     <div class="sp">subs</div>
#     <div class="gl">mourning rites</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876000</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹ֣ום </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">טֹ֑וב </div>
#     <div class="sp">adjv</div>
#     <div class="gl">good</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505927</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876001</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לַ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עֲשֹׂ֣ות </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876002</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹותָ֗ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876003</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְמֵי֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מִשְׁתֶּ֣ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">drinking</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
# ## Result 12
# (**sentence** `1229325`, **clause** `505922`, **phrase** `875983`, **word** `369666`, **clause** `505927`, **phrase** `876001`, **clause** `505928`, **phrase** `876005`, **word** `369720`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=20&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:20</a></div><div class="nd">1434580</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1229324</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505916</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875966</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875967</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּכְתֹּ֣ב </div>
#     <div class="sp">verb</div>
#     <div class="gl">write</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875968</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מָרְדֳּכַ֔י </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Mordecai</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875969</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְּבָרִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">word</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֑לֶּה </div>
#     <div class="sp">prde</div>
#     <div class="gl">these</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505917</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875970</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875971</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּשְׁלַ֨ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875972</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">סְפָרִ֜ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">letter</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875973</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִ֗ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505918</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875974</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינֹות֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">district</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מֶּ֣לֶךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲחַשְׁוֵרֹ֔ושׁ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Ahasuerus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505919</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875976</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875977</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">קְּרֹובִ֖ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">near</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505920</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875978</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875979</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
# ...
#
#     <div class="phrase">phrase <span class="nd">876002</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹותָ֗ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876003</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְמֵי֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מִשְׁתֶּ֣ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">drinking</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ<
# ## Result 19
# (**sentence** `1229325`, **clause** `505925`, **phrase** `875994`, **word** `369700`, **clause** `505927`, **phrase** `876001`, **clause** `505928`, **phrase** `876005`, **word** `369721`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=20&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:20</a></div><div class="nd">1434580</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1229324</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505916</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875966</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875967</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּכְתֹּ֣ב </div>
#     <div class="sp">verb</div>
#     <div class="gl">write</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875968</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מָרְדֳּכַ֔י </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Mordecai</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875969</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְּבָרִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">word</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֑לֶּה </div>
#     <div class="sp">prde</div>
#     <div class="gl">these</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505917</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875970</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875971</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּשְׁלַ֨ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875972</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">סְפָרִ֜ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">letter</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875973</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִ֗ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505918</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875974</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינֹות֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">district</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מֶּ֣לֶךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875975</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲחַשְׁוֵרֹ֔ושׁ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Ahasuerus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505919</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875976</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875977</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">קְּרֹובִ֖ים </div>
#     <div class="sp">adjv</div>
#     <div class="gl">near</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505920</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875978</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875979</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875980</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">רְחֹוקִֽים׃ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">remote</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esther&chapter=9&verse=22&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Esther 9:22</a></div><div class="nd">1434582</div>
#     </div>
#
# <div class="satom  R  hl">
#
#     <div class="sentence">sentence <span class="nd">1229325</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כַּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">as</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּמִ֗ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505924</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875988</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר־</div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875989</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">נָ֨חוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">settle</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875990</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875991</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְּהוּדִים֙ </div>
#     <div class="sp">adjv</div>
#     <div class="gl">Jewish</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875992</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֹ֣ויְבֵיהֶ֔ם </div>
#     <div class="sp">verb</div>
#     <div class="gl">be hostile</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r ">
#
#     <div class="clause">clause <span class="nd">505923</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">875987</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">חֹ֗דֶשׁ </div>
#     <div class="sp">subs</div>
#     <div class="gl">month</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505925</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875993</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֩ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">875994</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">נֶהְפַּ֨ךְ </div>
#     <div class="sp">verb</div>
#     <div class="gl">turn</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875995</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לָהֶ֤ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875996</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָּגֹון֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">grief</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875997</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׂמְחָ֔ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">joy</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">505926</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875998</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">875999</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֵ֖בֶל </div>
#     <div class="sp">subs</div>
#     <div class="gl">mourning rites</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876000</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יֹ֣ום </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">טֹ֑וב </div>
#     <div class="sp">adjv</div>
#     <div class="gl">good</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">505927</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">876001</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לַ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עֲשֹׂ֣ות </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876002</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹותָ֗ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">876003</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְמֵי֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">day</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מִשְׁתֶּ֣ה </div>
#     <div class="sp">subs</div>
#     <div class="gl">drinking</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ<
