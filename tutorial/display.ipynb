# %% [markdown]
# # Rich display
#
# We have a new module, `bhsa.py`, that can display every node in a shebanq-like way.
# It can also display query results obtained by Text-Fabric search.
#
# ## Install
#
# This module is part of the [BHSA](https://github.com/ETCBC/bhsa) repo, which you need to have to run TF on the Hebrew Bible anyway. So update your repo by `git pull origin master` or clone it again.
#
# ## Usage
#
# The new module makes the use of TF a bit easier. Yet there is an incantation to go through.
# See below.

# %%
import sys, os
from IPython.display import display, HTML

# %% [markdown]
# ## New incantation
# Here comes the new incantation.
# Note the `LOC` variable:
#
# * part 1: the place where you have your github repos
# * part 2: how you get from there to the BHSA repo
# * part 3: the name of this notebook (if you write your notebook, enter the name of *your* notebook)
#
# If you have your notebook in a github repo, you will get the link to its online version,
# on GitHub and on NBviewer.
#
# Note that handy documentation links are shown after loading.

# %%
LOC = ('~/github', 'etcbc/bhsa', 'display')
sys.path.append(os.path.expanduser(f'{LOC[0]}/{LOC[1]}/programs'))
from bhsa import Bhsa
B = Bhsa(*LOC)
B.api.makeAvailableIn(globals())
# Out:
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="{provenance of this corpus}">BHSA</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/0_home.html" title="{CORPUS} feature documentation">Feature docs</a> <a target="_blank" href="https://etcbc.github.io/bhsa/api.html" title="BHSA API documentation">BHSA API</a> <a target="_blank" href="https://github.com/Dans-labs/text-fabric/wiki/api" title="text-fabric-api">Text-Fabric API</a>
# This notebook online:
# <a target="_blank" href="http://nbviewer.jupyter.org/github/etcbc/bhsa/blob/master/tutorial/display.ipynb">NBViewer</a>
# <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/tutorial/display.ipynb">GitHub</a>
# <style>
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     direction: ltr;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.L,.catom.L,.patom.L {
#     border-left-style: none
# }
# .satom.R,.catom.R,.patom.R {
#     border-right-style: none
# }
# .h {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl;
# }
# .sp {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .gl {
#     font-family: sans-serif;
#     font-size: small;
#     color: #aaaaaa;
# }
# .vs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# </style>

# %% [markdown]
# A number of features has already been loaded.
# If you need more features, do it like this:

# %%
B.load('''
    vs vt
''')

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
B.pretty(651572)
# Out:
# <div class="atoms  ">
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651572</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עַ֣ל </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֑יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Verses
# Now a couple of verses:

# %%
verse1 = T.nodeFromSection(('Genesis', 1, 7))
verse2 = T.nodeFromSection(('Genesis', 1, 17))

# %%
B.pretty(verse1 )
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a></div><div class="nd">1414196</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172226</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427571</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651562</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651563</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַּ֣עַשׂ </div>
#     <div class="sp">verb</div>
#     <div class="gl">make</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651564</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִים֮ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651565</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶת־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִיעַ֒ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172227</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause">clause <span class="nd">427572</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651566</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651567</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַּבְדֵּ֗ל </div>
#     <div class="sp">verb</div>
#     <div class="gl">separate</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֵּ֤ין </div>
#     <div class="sp">subs</div>
#     <div class="gl">interval</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַּ֨יִם֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">water</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427573</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651569</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁר֙ </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase">phrase <span class="nd">651570</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">תַּ֣חַת </div>
#     <div class="sp">subs</div>
#     <div class="gl">under part</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">651570</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֔יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r ">
#
#     <div class="clause">clause <span class="nd">427572</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase">phrase <span class="nd">651568</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בֵ֣ין </div>
#     <div class="sp">subs</div>
#     <div class="gl">interval</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַּ֔יִם </div>
#     <div class="sp">subs</div>
#     <div class="gl">water</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427574</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651571</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲשֶׁ֖ר </div>
#     <div class="sp">conj</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651572</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מֵ</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">עַ֣ל </div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לָ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h"></div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָקִ֑יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1172228</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">427575</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651573</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַֽ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651574</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יְהִי־</div>
#     <div class="sp">verb</div>
#     <div class="gl">be</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">651575</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֵֽן׃ </div>
#     <div class="sp">advb</div>
#     <div class="gl">thus</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# The next verse without all those node numbers.

# %%
B.pretty(verse2, withNodes=False)
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#     </div>
#
# <div class="satom  L ">
#
#     <div class="sentence">sentence
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יִּתֵּ֥ן </div>
#     <div class="sp">verb</div>
#     <div class="gl">give</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹתָ֛ם </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;object marker></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִ֖ים </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רְקִ֣יעַ </div>
#     <div class="sp">subs</div>
#     <div class="gl">firmament</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הַ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שָּׁמָ֑יִם </div>
#     <div class="sp">subs</div>
#     <div class="gl">heavens</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָאִ֖יר </div>
#     <div class="sp">verb</div>
#     <div class="gl">be light</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הָ</div>
#     <div class="sp">art</div>
#     <div class="gl">the</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אָֽרֶץ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">earth</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Query results
# We run a TF query and show some of its results with a lot of pomp and circumstance.
# The query is written by Stephen Ku, and he is the one who prompted me to write
# rich display function for query results.

# %%
ellipQuery = '''
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
'''

# %% [markdown]
# Instead of running `T.search()`, we do `B.search()`.

# %%
results = B.search(ellipQuery)
len(results)
# Out:
# 1410

# %% [markdown]
# Here it comes: the `B.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
B.show(results, 10, 20, withNodes=True)
# Out:
# ## Result 10
# (**sentence** `1230794`, **clause** `508186`, **phrase** `882601`, **word** `381188`, **clause** `508190`, **phrase** `882612`, **clause** `508192`, **phrase** `882618`, **word** `381221`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=14&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:14</a></div><div class="nd">1435123</div>
#     </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508186</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882599</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כָּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">like</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳבֵ֗ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">opposite</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דִּי֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882600</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִן־</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳדָ֨ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">before</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֜א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׁבְעַ֤ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">seven</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֨הִי֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882601</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">שְׁלִ֔יחַ </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508187</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882602</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בַקָּרָ֥א </div>
#     <div class="sp">verb</div>
#     <div class="gl">search</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882603</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְה֖וּד </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Judaea</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֑ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882604</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דָ֥ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">law</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהָ֖ךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508188</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882605</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882606</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ידָֽךְ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">hand</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=15&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:15</a></div><div class="nd">1435124</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508189</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882607</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882608</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הֵיבָלָ֖ה </div>
#     <div class="sp">verb</div>
#     <div class="gl">bring</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882609</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְהַ֑ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508190</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882610</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּֽי־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882611</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֣א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֗והִי </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882612</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדַּ֨בוּ֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882613</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לֶ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָ֣הּ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יִשְׂרָאֵ֔ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Israel</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508191</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882614</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882615</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֖ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882616</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִשְׁכְּנֵֽהּ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">abode</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:16</a></div><div class="nd">1435125</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508192</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882617</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882618</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">כֹל֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְהַ֔ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508193</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882619</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֣י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882620</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">תְהַשְׁכַּ֔ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">find</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882621</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כֹ֖ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינַ֣ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">province</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בָּבֶ֑ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Babylon</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508194</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882622</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עִם֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">with</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדָּב֨וּת </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882623</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַמָּ֤א </div>
#     <div class="sp">subs</div>
#     <div class="gl">people</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָֽהֲנַיָּא֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">priest</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508195</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882624</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִֽתְנַדְּבִ֔ין </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882625</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בֵ֥ית </div>
#     <div class="sp">subs</div>
#     <div class="gl">house</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהֲהֹ֖ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508196</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882626</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882627</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶֽם׃ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ## Result 11
# (**sentence** `1230794`, **clause** `508186`, **phrase** `882601`, **word** `381188`, **clause** `508190`, **phrase** `882612`, **clause** `508192`, **phrase** `882618`, **word** `381222`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=14&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:14</a></div><div class="nd">1435123</div>
#     </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508186</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882599</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כָּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">like</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳבֵ֗ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">opposite</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דִּי֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882600</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִן־</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳדָ֨ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">before</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֜א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׁבְעַ֤ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">seven</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֨הִי֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882601</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">שְׁלִ֔יחַ </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508187</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882602</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בַקָּרָ֥א </div>
#     <div class="sp">verb</div>
#     <div class="gl">search</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882603</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְה֖וּד </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Judaea</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֑ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882604</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דָ֥ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">law</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהָ֖ךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508188</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882605</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882606</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ידָֽךְ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">hand</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=15&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:15</a></div><div class="nd">1435124</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508189</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882607</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882608</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הֵיבָלָ֖ה </div>
#     <div class="sp">verb</div>
#     <div class="gl">bring</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882609</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְהַ֑ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508190</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882610</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּֽי־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882611</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֣א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֗והִי </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882612</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדַּ֨בוּ֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882613</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לֶ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָ֣הּ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יִשְׂרָאֵ֔ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Israel</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508191</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882614</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882615</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֖ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882616</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִשְׁכְּנֵֽהּ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">abode</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:16</a></div><div class="nd">1435125</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508192</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882617</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882618</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֹל֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word   hl">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְהַ֔ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508193</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882619</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֣י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882620</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">תְהַשְׁכַּ֔ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">find</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882621</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כֹ֖ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינַ֣ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">province</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בָּבֶ֑ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Babylon</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508194</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882622</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עִם֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">with</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדָּב֨וּת </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882623</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַמָּ֤א </div>
#     <div class="sp">subs</div>
#     <div class="gl">people</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָֽהֲנַיָּא֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">priest</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508195</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882624</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִֽתְנַדְּבִ֔ין </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882625</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בֵ֥ית </div>
#     <div class="sp">subs</div>
#     <div class="gl">house</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהֲהֹ֖ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508196</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882626</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882627</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶֽם׃ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ## Result 12
# (**sentence** `1230794`, **clause** `508187`, **phrase** `882602`, **word** `381190`, **clause** `508190`, **phrase** `882612`, **clause** `508192`, **phrase** `882618`, **word** `381224`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=14&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:14</a></div><div class="nd">1435123</div>
#     </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508186</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882599</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כָּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">like</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳבֵ֗ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">opposite</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דִּי֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882600</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִן־</div>
#     <div class="sp">prep</div>
#     <div class="gl">from</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">קֳדָ֨ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">before</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֜א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שִׁבְעַ֤ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">seven</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֨הִי֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882601</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">שְׁלִ֔יחַ </div>
#     <div class="sp">verb</div>
#     <div class="gl">send</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508187</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882602</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word   hl">
#
#     <div class="h">בַקָּרָ֥א </div>
#     <div class="sp">verb</div>
#     <div class="gl">search</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882603</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יְה֖וּד </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Judaea</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">לִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֑ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882604</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דָ֥ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">law</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהָ֖ךְ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508188</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882605</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882606</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ידָֽךְ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">hand</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=15&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:15</a></div><div class="nd">1435124</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508189</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882607</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882608</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הֵיבָלָ֖ה </div>
#     <div class="sp">verb</div>
#     <div class="gl">bring</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882609</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">דְהַ֑ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508190</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882610</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּֽי־</div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882611</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מַלְכָּ֣א </div>
#     <div class="sp">subs</div>
#     <div class="gl">king</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יָעֲטֹ֗והִי </div>
#     <div class="sp">verb</div>
#     <div class="gl">advise</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882612</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדַּ֨בוּ֙ </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882613</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לֶ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָ֣הּ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">יִשְׂרָאֵ֔ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Israel</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508191</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882614</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882615</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִֽ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶ֖ם </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882616</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִשְׁכְּנֵֽהּ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">abode</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:16</a></div><div class="nd">1435125</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">508192</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882617</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">882618</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֹל֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כְּסַ֣ף </div>
#     <div class="sp">subs</div>
#     <div class="gl">silver</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וּ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word   hl">
#
#     <div class="h">דְהַ֔ב </div>
#     <div class="sp">subs</div>
#     <div class="gl">gold</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508193</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882619</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֣י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882620</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">תְהַשְׁכַּ֔ח </div>
#     <div class="sp">verb</div>
#     <div class="gl">find</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882621</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כֹ֖ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מְדִינַ֣ת </div>
#     <div class="sp">subs</div>
#     <div class="gl">province</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בָּבֶ֑ל </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Babylon</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508194</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882622</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עִם֩ </div>
#     <div class="sp">prep</div>
#     <div class="gl">with</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">הִתְנַדָּב֨וּת </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882623</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַמָּ֤א </div>
#     <div class="sp">subs</div>
#     <div class="gl">people</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">וְ</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">כָֽהֲנַיָּא֙ </div>
#     <div class="sp">subs</div>
#     <div class="gl">priest</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508195</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882624</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִֽתְנַדְּבִ֔ין </div>
#     <div class="sp">verb</div>
#     <div class="gl">be willing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882625</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְ</div>
#     <div class="sp">prep</div>
#     <div class="gl">to</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בֵ֥ית </div>
#     <div class="sp">subs</div>
#     <div class="gl">house</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלָהֲהֹ֖ם </div>
#     <div class="sp">subs</div>
#     <div class="gl">god</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508196</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882626</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">דִּ֥י </div>
#     <div class="sp">prep</div>
#     <div class="gl">&lt;relative></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">882627</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בִ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">ירוּשְׁלֶֽם׃ </div>
#     <div class="sp">nmpr</div>
#     <div class="gl">Jerusalem</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ## Result 13
# (**sentence** `1230794`, **clause** `508187`, **phrase** `882602`, **word** `381190`, **clause** `508190`, **phrase** `882612`, **clause** `508192`, **phrase** `882618`, **word** `381221`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Ezra&chapter=7&verse=14&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 7:14</a></div><div class="nd">1435123</div>
#     </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1230794</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">508186</span>
#     </div>
# ...
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הָטְבָּ֑עוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">sink</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500049</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860245</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹ֥ו </div>
#     <div class="sp">conj</div>
#     <div class="gl">or</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860246</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִֽי־</div>
#     <div class="sp">prin</div>
#     <div class="gl">who</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860247</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">יָ֝רָ֗ה </div>
#     <div class="sp">verb</div>
#     <div class="gl">cast</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860248</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶ֣בֶן </div>
#     <div class="sp">subs</div>
#     <div class="gl">stone</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">פִּנָּתָֽהּ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">corner</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Job&chapter=38&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Job 38:7</a></div><div class="nd">1432796</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500050</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860249</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָן־</div>
#     <div class="sp">verb</div>
#     <div class="gl">cry of joy</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860250</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַ֭חַד </div>
#     <div class="sp">subs</div>
#     <div class="gl">gathering</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860251</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֹּ֣וכְבֵי </div>
#     <div class="sp">subs</div>
#     <div class="gl">star</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בֹ֑קֶר </div>
#     <div class="sp">subs</div>
#     <div class="gl">morning</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">500051</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860252</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ֝</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860253</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יָּרִ֗יעוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">shout</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860254</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בְּנֵ֥י </div>
#     <div class="sp">subs</div>
#     <div class="gl">son</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִֽים׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Job&chapter=38&verse=9&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Job 38:9</a></div><div class="nd">1432798</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">500055</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860262</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שׂוּמִ֣י </div>
#     <div class="sp">verb</div>
#     <div class="gl">put</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860263</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עָנָ֣ן </div>
#     <div class="sp">subs</div>
#     <div class="gl">cloud</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860264</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְבֻשֹׁ֑ו </div>
#     <div class="sp">subs</div>
#     <div class="gl">clothing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500056</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860265</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ֝</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860266</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">עֲרָפֶ֗ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">darkness</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860267</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">חֲתֻלָּתֹֽו׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">swaddling band</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ## Result 19
# (**sentence** `1225194`, **clause** `500049`, **phrase** `860247`, **word** `345489`, **clause** `500051`, **phrase** `860253`, **clause** `500056`, **phrase** `860266`, **word** `345517`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Job&chapter=38&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Job 38:6</a></div><div class="nd">1432795</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence">sentence <span class="nd">1225193</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">500048</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860242</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עַל־</div>
#     <div class="sp">prep</div>
#     <div class="gl">upon</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">מָ֭ה </div>
#     <div class="sp">prin</div>
#     <div class="gl">what</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860243</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֲדָנֶ֣יהָ </div>
#     <div class="sp">subs</div>
#     <div class="gl">pedestal</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860244</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">הָטְבָּ֑עוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">sink</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500049</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860245</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֹ֥ו </div>
#     <div class="sp">conj</div>
#     <div class="gl">or</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860246</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">מִֽי־</div>
#     <div class="sp">prin</div>
#     <div class="gl">who</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860247</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">יָ֝רָ֗ה </div>
#     <div class="sp">verb</div>
#     <div class="gl">cast</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860248</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">אֶ֣בֶן </div>
#     <div class="sp">subs</div>
#     <div class="gl">stone</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">פִּנָּתָֽהּ׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">corner</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Job&chapter=38&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Job 38:7</a></div><div class="nd">1432796</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">500050</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860249</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">רָן־</div>
#     <div class="sp">verb</div>
#     <div class="gl">cry of joy</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860250</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יַ֭חַד </div>
#     <div class="sp">subs</div>
#     <div class="gl">gathering</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860251</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כֹּ֣וכְבֵי </div>
#     <div class="sp">subs</div>
#     <div class="gl">star</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בֹ֑קֶר </div>
#     <div class="sp">subs</div>
#     <div class="gl">morning</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500051</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860252</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ֝</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860253</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">יָּרִ֗יעוּ </div>
#     <div class="sp">verb</div>
#     <div class="gl">shout</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860254</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">כָּל־</div>
#     <div class="sp">subs</div>
#     <div class="gl">whole</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">בְּנֵ֥י </div>
#     <div class="sp">subs</div>
#     <div class="gl">son</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">אֱלֹהִֽים׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">god(s)</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Job&chapter=38&verse=9&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Job 38:9</a></div><div class="nd">1432798</div>
#     </div>
#
# <div class="satom  R L  hl">
#
#     <div class="sentence">sentence <span class="nd">1225194</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause">clause <span class="nd">500055</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860262</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">בְּ</div>
#     <div class="sp">prep</div>
#     <div class="gl">in</div>
#
#
# </div>
#
# <div class="word  ">
#
#     <div class="h">שׂוּמִ֣י </div>
#     <div class="sp">verb</div>
#     <div class="gl">put</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860263</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">עָנָ֣ן </div>
#     <div class="sp">subs</div>
#     <div class="gl">cloud</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860264</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">לְבֻשֹׁ֑ו </div>
#     <div class="sp">subs</div>
#     <div class="gl">clothing</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause">clause <span class="nd">500056</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860265</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">וַ֝</div>
#     <div class="sp">conj</div>
#     <div class="gl">and</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase">phrase <span class="nd">860266</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
#
#     <div class="h">עֲרָפֶ֗ל </div>
#     <div class="sp">subs</div>
#     <div class="gl">darkness</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase">phrase <span class="nd">860267</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
#
#     <div class="h">חֲתֻלָּתֹֽו׃ </div>
#     <div class="sp">subs</div>
#     <div class="gl">swaddling band</div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
