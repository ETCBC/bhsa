# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("ETCBC/bhsa:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/bhsa/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/bhsa/tf/2021</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/phono/tf/2021</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/parallels/tf/2021</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">TF API 12.1.2</a>, <a target="_blank" href="https://github.com/ETCBC/bhsa/blob/master/app" title="ETCBC/bhsa app">ETCBC/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
# A.zipAll()

# %%
NE = A.makeNer()
# Out:
# <style>:root {
#   --ent-markup-color: #ddbb00;
#   --ent-markup-bg: #ffddbb;
# }
#
#
# code {
#   white-space: pre-wrap;
# }
#
# code.w {
#   white-space: pre;
# }
#
# p.queried,span.queried {
#   border-radius: 0.2rem;
#   background-color: yellow;
#   padding: 0 0.3rem;
# }
#
# span.found {
#   background-color: #aaddff;
#   border-radius: 0.2rem;
#   padding: 0 0.3rem;
# }
#
# div.b {
#   padding: 0.2rem 0.1rem;
#   border-bottom: 2pt solid #eeeeee;
#   margin-bottom: 0.2rem;
#   line-height: 150%;
#   content-visible: auto;
#   contain-intrinsic-size: 1rem 2rem;
# }
#
# span.ei {
#   border-bottom: 0.3rem solid orange ! important;
# }
# span.ei.noformat {
#   border-bottom: 0 ! important;
# }
# span.es,span.ee {
#   font-family: monospace;
#   font-size: x-small;
#   font-weight: bold;
#   color: var(--ent-markup-color);
# }
# span.es {
#   padding-left: 0.1em;
#   margin-left: 0.2em;
# }
# span.ee {
#   padding-right: 0.1em;
#   margin-right: 0.2em;
# }
# span.bhl {
# ...

# %%
NE.setSet("")
# Out:
# Annotation set ent-nodes has 0 annotations

# %%
results = NE.filterContent(showStats=True)
# Out:
# 23213 verses satisfy the filter
# Combined features match:
# Feature eid: found the following values:
# Feature kind: found the following values:
# 23213 verses

# %%
b = results[0][0]

A.plain(b)
# Out:
# <div class="rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></span>  <span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="txtu hbo">בָּרָ֣א </span><span class="txtu hbo">אֱלֹהִ֑ים </span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הַ</span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></div>

# %%
NE.showContent(results, end=11)
# Out:
# <div class="buckets rtl"><div class="b rtl"><span class="bh rtl"><span node="1414389" class="bhl ltr" title="show context">Genesis 1:1</span></span> <span class="rtl"><span class=" txtu hbo " t="1">ב</span><span class=" txtu hbo " t="2">ראשׁית</span> <span class=" txtu hbo " t="3">ברא</span> <span class=" txtu hbo " t="4">אלהים</span> <span class=" txtu hbo " t="5">את</span> <span class=" txtu hbo " t="6">ה</span><span class=" txtu hbo " t="7">שׁמים</span> <span class=" txtu hbo " t="8">ו</span><span class=" txtu hbo " t="9">את</span> <span class=" txtu hbo " t="10">ה</span><span class=" txtu hbo " t="11">ארץ</span>׃ </span></div><div class="b rtl"><span class="bh rtl"><span node="1414390" class="bhl ltr" title="show context">Genesis 1:2</span></span> <span class="rtl"><span class=" txtu hbo " t="12">ו</span><span class=" txtu hbo " t="13">ה</span><span class=" txtu hbo " t="14">ארץ</span> <span class=" txtu hbo " t="15">היתה</span> <span class=" txtu hbo " t="16">תהו</span> <span cl
# ...
