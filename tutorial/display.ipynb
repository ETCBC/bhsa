# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Install" data-toc-modified-id="Install-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Install</a></span></li><li><span><a href="#Usage" data-toc-modified-id="Usage-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Usage</a></span></li><li><span><a href="#Call-up-more-power" data-toc-modified-id="Call-up-more-power-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Call up more power</a></span></li></ul></div>

# %% [markdown]
# # Rich display
#
# We have a new module, `bhsa.py`, that can display every node in a shebanq-like way.
# It can also display query results obtained by Text-Fabric search.
#
# ## Install
#
# This module is part of the [BHSA](https://github.com/ETCBC/bhsa) repo, which you need to have to run TF on the Hebrew Bible anyway. So update your repo by `git pull origin master` or clone it again.
#
# ## Usage
#
# The new module makes the use of TF a bit easier.

# %%
import sys, os
from IPython.display import display, HTML
from tf.fabric import Fabric
from tf.extra.bhsa import Bhsa

# %% [markdown]
# Specify locations.

# %%
VERSION = '2017'
DATABASE = '~/github/etcbc'
BHSA = f'bhsa/tf/{VERSION}'
PHONO = f'phono/tf/{VERSION}'

# %% [markdown]
# Call Text-Fabric in the usual way.

# %%
TF = Fabric(locations=[DATABASE], modules=[BHSA, PHONO], silent=False )
# Out:
# This is Text-Fabric 4.0.1
# Api reference : https://dans-labs.github.io/text-fabric/Api/General/
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 118 features found and 0 ignored

# %%
api = TF.load('''
    vs vt
''', silent=True)
api.makeAvailableIn(globals())

# %% [markdown]
# ## Call up more power
#
#
# If you have your notebook in a github repo, you will get the link to its online version,
# on GitHub and on NBviewer.
# provided you pass the name of your notebook.
#
# Note that handy documentation links are shown after loading.

# %%
B = Bhsa(api, 'display', version=VERSION)
# Out:
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="{provenance of this corpus}">BHSA</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/2017/0_home.html" title="{CORPUS} feature documentation">Feature docs</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/Bhsa/" title="BHSA API documentation">BHSA API</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/" title="text-fabric-api">Text-Fabric API 4.0.1</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#search-templates" title="Search Templates Introduction and Reference">Search Reference</a>
# This notebook online:
# <a target="_blank" href="http://nbviewer.jupyter.org/github/etcbc/bhsa/blob/master/tutorial/display.ipynb">NBViewer</a>
# <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/tutorial/display.ipynb">GitHub</a>
# <style>
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     direction: ltr;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lex {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.L,.catom.L,.patom.L {
#     border-left-style: none
# }
# .satom.R,.catom.R,.patom.R {
#     border-right-style: none
# }
# .h,.h :visited,.h :link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .sp,.sp :visited,.sp :link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .vl {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vvs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vvt {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .gl {
#     font-family: sans-serif;
#     font-size: small;
#     color: #aaaaaa;
# }
# .vs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# </style>

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
phrase = 651572
B.pretty(phrase)
# Out:
# <div class="atoms  ">
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651572</span>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">מֵ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></div>
# <div class="gl">from</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">עַ֣ל </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></div>
# <div class="gl">upon</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">לָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h"></div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">רָקִ֑יעַ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></div>
# <div class="gl">firmament</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Where is this phrase on SHEBANQ?

# %%
HTML(B.shbLink(phrase))
# Out:
# <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a>

# %% [markdown]
# A link to another passage:

# %%
z = T.nodeFromSection(('Ezra', 3, 4))

# %%
HTML(B.shbLink(z))
# Out:
# <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esra&chapter=3&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 3:4</a>

# %% [markdown]
# # Verses
# Now a couple of verses:

# %%
verse1 = T.nodeFromSection(('Genesis', 1, 7))
verse2 = T.nodeFromSection(('Genesis', 1, 17))

# %%
B.pretty(verse1 )
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a></div><div class="nd">1414196</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">sentence</a> <span class="nd">1172226</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">clause</a> <span class="nd">427571</span>  <span class="rela">NA</span> <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651562</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651563</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">יַּ֣עַשׂ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">verb</a></div>
# <div class="gl">make</div>
# <div class="vvs">qal</div>
# <div class="vvt">wayq</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651564</span>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֱלֹהִים֮ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></div>
# <div class="gl">god(s)</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651565</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">רָקִיעַ֒ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></div>
# <div class="gl">firmament</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">sentence</a> <span class="nd">1172227</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">clause</a> <span class="nd">427572</span>  <span class="rela">NA</span> <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651566</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651567</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">יַּבְדֵּ֗ל </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">verb</a></div>
# <div class="gl">separate</div>
# <div class="vvs">hif</div>
# <div class="vvt">wayq</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a> <span class="nd">651568</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">בֵּ֤ין </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></div>
# <div class="gl">interval</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">מַּ֨יִם֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></div>
# <div class="gl">water</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="http

# %% [markdown]
# The next verse without all those node numbers.

# %%
B.pretty(verse2, withNodes=False)
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#     </div>
#
# <div class="satom  L ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">sentence</a>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>   <span class="rela">NA</span> <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">יִּתֵּ֥ן </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></div>
# <div class="gl">give</div>
# <div class="vvs">qal</div>
# <div class="vvt">wayq</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֹתָ֛ם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֱלֹהִ֖ים </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
# <div class="gl">god(s)</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">בִּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
# <div class="gl">in</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">רְקִ֣יעַ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
# <div class="gl">firmament</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">שָּׁמָ֑יִם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
# <div class="gl">heavens</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>   <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָאִ֖יר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></div>
# <div class="gl">be light</div>
# <div class="vvs">hif</div>
# <div class="vvt">infc</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">עַל־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
# <div class="gl">upon</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אָֽרֶץ׃ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
# <div class="gl">earth</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Now we selectively remove a few features from the display:

# %%
B.pretty(verse2, withNodes=False, suppress={'gloss', 'typ'})
# Out:
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#     </div>
#
# <div class="satom  L ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">sentence</a>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>   <span class="rela">NA</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Conj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">conj</a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">יִּתֵּ֥ן </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></div>
# <div class="vvs">qal</div>
# <div class="vvt">wayq</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Objc</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֹתָ֛ם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Subj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֱלֹהִ֖ים </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">בִּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">רְקִ֣יעַ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">שָּׁמָ֑יִם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>   <span class="rela">Adju</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָאִ֖יר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></div>
# <div class="vvs">hif</div>
# <div class="vvt">infc</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">עַל־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אָֽרֶץ׃ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Query results
# We run a TF query and show some of its results with a lot of pomp and circumstance.
# The query is written by Stephen Ku, and he is the one who prompted me to write
# rich display function for query results.

# %%
ellipQuery = '''
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
'''

# %% [markdown]
# Instead of running `T.search()`, we do `B.search()`.

# %%
results = B.search(ellipQuery)
len(results)
# Out:
# 1410

# %% [markdown]
# Here it comes: the `B.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
B.show(results, 10, 20, withNodes=True)
# Out:
# ##### Passage 20
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 35:16</a></div><div class="nd">1416737</div>
#     </div>
#
# <div class="satom  R L ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:10">sentence</a> <span class="nd">1179715</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l  hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">clause</a> <span class="nd">437343</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l  hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">phrase</a> <span class="nd">681090</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֵ֣ת׀ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">מִזְבַּ֣ח </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">subs</a></div>
# <div class="gl">altar</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">עֹלָ֗ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">subs</a></div>
# <div class="gl">burnt-offering</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">מִכְבַּ֤ר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">subs</a></div>
# <div class="gl">lattice</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">נְּחֹ֨שֶׁת֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">subs</a></div>
# <div class="gl">bronze</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">clause</a> <span class="nd">437344</span>  <span class="rela">Attr</span> <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">phrase</a> <span class="nd">681091</span>  <span class="function">Rela</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֲשֶׁר־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">conj</a></div>
# <div class="gl">&lt;relative></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">phrase</a> <span class="nd">681092</span>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לֹ֔ו </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r  hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">clause</a> <span class="nd">437343</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r  hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">phrase</a> <span class="nd">681090</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">בַּדָּ֖יו </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">subs</a></div>
# <div class="gl">linen, part, stave</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:16">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word
# ##### Passage 21
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 35:17</a></div><div class="nd">1416738</div>
#     </div>
#
# <div class="satom  R L ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:10">sentence</a> <span class="nd">1179715</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">clause</a> <span class="nd">437345</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">phrase</a> <span class="nd">681093</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֵ֚ת </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">קַלְעֵ֣י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">curtain</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הֶ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">חָצֵ֔ר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">court</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">עַמֻּדָ֖יו </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">pillar</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">אֲדָנֶ֑יהָ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">pedestal</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֵ֕ת </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">מָסַ֖ךְ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">covering</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">שַׁ֥עַר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">gate</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הֶ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">חָצֵֽר׃ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:17">subs</a></div>
# <div class="gl">court</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ##### Passage 22
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 35:18</a></div><div class="nd">1416739</div>
#     </div>
#
# <div class="satom  R L ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:10">sentence</a> <span class="nd">1179715</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">clause</a> <span class="nd">437346</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">phrase</a> <span class="nd">681094</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">יִתְדֹ֧ת </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">subs</a></div>
# <div class="gl">peg</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">מִּשְׁכָּ֛ן </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">subs</a></div>
# <div class="gl">dwelling-place</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">יִתְדֹ֥ת </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">subs</a></div>
# <div class="gl">peg</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הֶ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">חָצֵ֖ר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">subs</a></div>
# <div class="gl">court</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">מֵיתְרֵיהֶֽם׃ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=18&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:18">subs</a></div>
# <div class="gl">string</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# ##### Passage 23
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 35:19</a></div><div class="nd">1416740</div>
#     </div>
#
# <div class="satom  R ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:10">sentence</a> <span class="nd">1179715</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l  hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">clause</a> <span class="nd">437347</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l  hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">phrase</a> <span class="nd">681095</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">בִּגְדֵ֥י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">subs</a></div>
# <div class="gl">garment</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">שְּׂרָ֖ד </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">subs</a></div>
# <div class="gl">cord</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">clause</a> <span class="nd">437348</span>  <span class="rela">Spec</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">phrase</a> <span class="nd">681096</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">שָׁרֵ֣ת </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">verb</a></div>
# <div class="gl">serve</div>
# <div class="vvs">piel</div>
# <div class="vvt">infc</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">phrase</a> <span class="nd">681097</span>  <span class="function">Adju</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">בַּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">prep</a></div>
# <div class="gl">in</div>
#
# </div>
#
# <div class="word  ">
# <div class="h"></div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">קֹּ֑דֶשׁ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">subs</a></div>
# <div class="gl">holiness</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r  hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">clause</a> <span class="nd">437347</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  r l  hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">phrase</a> <span class="nd">681095</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">prep</a></div>
# <div class="gl">&lt;object marker></div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">בִּגְדֵ֤י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">subs</a></div>
# <div class="gl">garment</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">הַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word   hl">
# <div class="h">קֹּ֨דֶשׁ֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">subs</a></div>
# <div class="gl">holiness</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l  hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 35:19">phrase</a> <span class="nd">681095</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=35&verse=19&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=
# ##### Passage 24
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Leviticus 9:3</a></div><div class="nd">1417146</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">sentence</a> <span class="nd">1180553</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">clause</a> <span class="nd">438611</span>  <span class="rela">NA</span> <span class="typ">WxY0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685038</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685039</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶל־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">בְּנֵ֥י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">subs</a></div>
# <div class="gl">son</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">יִשְׂרָאֵ֖ל </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">nmpr</a></div>
# <div class="gl">Israel</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685040</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">תְּדַבֵּ֣ר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">verb</a></div>
# <div class="gl">speak</div>
# <div class="vvs">piel</div>
# <div class="vvt">impf</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">clause</a> <span class="nd">438612</span>  <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685041</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לֵ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אמֹ֑ר </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">verb</a></div>
# <div class="gl">say</div>
# <div class="vvs">qal</div>
# <div class="vvt">infc</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">sentence</a> <span class="nd">1180554</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">clause</a> <span class="nd">438613</span>  <span class="rela">NA</span> <span class="typ">ZIm0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685042</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
# <div class="h">קְח֤וּ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">verb</a></div>
# <div class="gl">take</div>
# <div class="vvs">qal</div>
# <div class="vvt">impv</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class="nd">685043</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">שְׂעִיר־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">subs</a></div>
# <div class="gl">he-goat</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">עִזִּים֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">subs</a></div>
# <div class="gl">goat</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">phrase</a> <span class
# ##### Passage 25
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Leviticus 9:4</a></div><div class="nd">1417147</div>
#     </div>
#
# <div class="satom  R ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=3&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:3">sentence</a> <span class="nd">1180554</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">clause</a> <span class="nd">438614</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685044</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685045</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">שֹׁ֨ור </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">subs</a></div>
# <div class="gl">bullock</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וָ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אַ֜יִל </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">subs</a></div>
# <div class="gl">ram, despot</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685045</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לִ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">שְׁלָמִ֗ים </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">subs</a></div>
# <div class="gl">final offer</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">clause</a> <span class="nd">438615</span>  <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685046</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לִ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">זְבֹּ֨חַ֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">verb</a></div>
# <div class="gl">slaughter</div>
# <div class="vvs">qal</div>
# <div class="vvt">infc</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685047</span>  <span class="function">Adju</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לִ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">פְנֵ֣י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">subs</a></div>
# <div class="gl">face</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">יְהוָ֔ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">nmpr</a></div>
# <div class="gl">YHWH</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">clause</a> <span class="nd">438616</span>  <span class="rela">NA</span> <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">phrase</a> <span class="nd">685048</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=9&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 9:4">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/heb
# ##### Passage 26
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Leviticus 14:21</a></div><div class="nd">1417322</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">sentence</a> <span class="nd">1181043</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">clause</a> <span class="nd">439276</span>  <span class="rela">NA</span> <span class="typ">AjCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">phrase</a> <span class="nd">687072</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">phrase</a> <span class="nd">687073</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אִם־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">conj</a></div>
# <div class="gl">if</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">phrase</a> <span class="nd">687074</span>  <span class="function">PreC</span> <span class="typ">AdjP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">דַּ֣ל </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">adjv</a></div>
# <div class="gl">poor</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">phrase</a> <span class="nd">687075</span>  <span class="function">Subj</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">ה֗וּא </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">prps</a></div>
# <div class="gl">he</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">sentence</a> <span class="nd">1181044</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&chapter=14&verse=21&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Leviticus 14:21">clause</a> <span class="nd">439277</span>  <span class="rela">NA</span> <span class="typ">Ptcp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
# ...
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Micah 3:8</a></div><div class="nd">1428810</div>
#     </div>
#
# <div class="satom   hl">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">sentence</a> <span class="nd">1216166</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">clause</a> <span class="nd">487760</span>  <span class="rela">NA</span> <span class="typ">WXQt</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828730</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828731</span>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אוּלָ֗ם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">advb</a></div>
# <div class="gl">but</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828732</span>  <span class="function">Subj</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אָנֹכִ֞י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">prps</a></div>
# <div class="gl">i</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828733</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
# <div class="h">מָלֵ֤אתִי </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">verb</a></div>
# <div class="gl">be full</div>
# <div class="vvs">qal</div>
# <div class="vvt">perf</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828734</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">כֹ֨חַ֙ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">subs</a></div>
# <div class="gl">strength</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828735</span>  <span class="function">Adju</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֶת־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">prep</a></div>
# <div class="gl">together with</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">ר֣וּחַ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">subs</a></div>
# <div class="gl">wind</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">יְהוָ֔ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">nmpr</a></div>
# <div class="gl">YHWH</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828734</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">phrase</a> <span class="nd">828734</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">מִשְׁפָּ֖ט </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">subs</a></div>
# <div class="gl">justice</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וּ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">גְבוּרָ֑ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">subs</a></div>
# <div class="gl">strength</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=3&verse=8&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 3:8">clause</a
# ##### Passage 100
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Psalms 24:4</a></div><div class="nd">1429657</div>
#     </div>
#
# <div class="satom  L  hl">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">sentence</a> <span class="nd">1218631</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">clause</a> <span class="nd">491177</span>  <span class="rela">Subj</span> <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837656</span>  <span class="function">PreC</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">נְקִ֥י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">adjv</a></div>
# <div class="gl">innocent</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">כַפַּ֗יִם </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">subs</a></div>
# <div class="gl">palm</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">וּֽ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">בַר־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">adjv</a></div>
# <div class="gl">pure</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">לֵ֫בָ֥ב </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">subs</a></div>
# <div class="gl">heart</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">clause</a> <span class="nd">491178</span>  <span class="rela">Attr</span> <span class="typ">xQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837657</span>  <span class="function">Rela</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אֲשֶׁ֤ר׀ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">conj</a></div>
# <div class="gl">&lt;relative></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837658</span>  <span class="function">Nega</span> <span class="typ">NegP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לֹא־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">nega</a></div>
# <div class="gl">not</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom   hl">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837659</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word   hl">
# <div class="h">נָשָׂ֣א </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">verb</a></div>
# <div class="gl">lift</div>
# <div class="vvs">qal</div>
# <div class="vvt">perf</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837660</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">לַ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">prep</a></div>
# <div class="gl">to</div>
#
# </div>
#
# <div class="word  ">
# <div class="h"></div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">art</a></div>
# <div class="gl">the</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">שָּׁ֣וְא </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">subs</a></div>
# <div class="gl">vanity</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">phrase</a> <span class="nd">837661</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">נַפְשִׁ֑י </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">subs</a></div>
# <div class="gl">soul</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom   hl">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Psalms 24:4">clause</a> <span class="nd">491179</span>  <span class="rela">Coor</span> <span class="typ">WxQ0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&chapter=24&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&
