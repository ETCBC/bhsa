# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.fabric import Fabric
from tf.app import use

# %%
TF = Fabric(locations="~/github/etcbc/bhsa/tf/2017", silent=False)
# Out:
# This is Text-Fabric 9.0.1
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 115 features found and 0 ignored

# %%
api = TF.load('''
mother lex sp gn nu vt vs typ function prs book language voc_lex lex0 lex_utf8 g_cons g_lex g_word g_lex_utf8 g_cons_utf8 gloss domain txt kind g_word_utf8 nme number pargr pfm pdp st det prs_gn prs_nu ps prs_ps rela nametype nme
''', silent=False)
# Out:
#   0.00s loading features ...
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#   4.85s All features loaded/computed - for details use TF.isLoaded()

# %%
TF.isLoaded()
# Out:
# __boundary__         computed   ~/github/etcbc/bhsa/tf/2017
# __levDown__          computed   ~/github/etcbc/bhsa/tf/2017
# __levUp__            computed   ~/github/etcbc/bhsa/tf/2017
# __levels__           computed   ~/github/etcbc/bhsa/tf/2017
# __order__            computed   ~/github/etcbc/bhsa/tf/2017
# __rank__             computed   ~/github/etcbc/bhsa/tf/2017
# __sections__         computed   ~/github/etcbc/bhsa/tf/2017
# __structure__        NOT LOADED
# book                 node (str) ~/github/etcbc/bhsa/tf/2017
# book@am              node (str) ~/github/etcbc/bhsa/tf/2017
# book@ar              node (str) ~/github/etcbc/bhsa/tf/2017
# book@bn              node (str) ~/github/etcbc/bhsa/tf/2017
# book@da              node (str) ~/github/etcbc/bhsa/tf/2017
# book@de              node (str) ~/github/etcbc/bhsa/tf/2017
# book@el              node (str) ~/github/etcbc/bhsa/tf/2017
# book@en              node (str) ~/github/etcbc/bhsa/tf/2017
# ...

# %%
hasattr(api.C, "__boundary__".strip("_"))
# Out:
# True

# %%
A = use("bhsa")
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/c</span>
# This is Text-Fabric 9.0.1
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 120 features found and 0 ignored
# ...

# %%
A.isLoaded()
# Out:
# __boundary__         computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __levDown__          computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __levUp__            computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __levels__           computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __order__            computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __rank__             computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __sections__         computed   ~/text-fabric-data/etcbc/bhsa/tf/c
# __structure__        NOT LOADED
# book                 node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@am              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@ar              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@bn              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@da              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@de              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# book@el              node (str) ~/text-fabric-data/etcbc/bhsa/tf/c
# ...
